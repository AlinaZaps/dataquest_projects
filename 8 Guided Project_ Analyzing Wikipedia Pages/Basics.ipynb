# %%
import os
import time
import concurrent.futures
from collections import Counter
import re
from bs4 import BeautifulSoup

# %% [markdown]
# # Analyzing Wikipedia Pages
#
#
# In this guided project, we'll be analyzing 54 megabytes worth of articles to figure out patterns in the Wikipedia writing and content presentation style. The articles were scraped by hitting random pages on Wikipedia, then downloading the contents using the requests package. The scraping code is in this folder, in the scrape_random.py file
#
# Our main goals will be to:
#
# - Extract only the text from the Wikipedia pages, and remove all HTML and Javascript markup.
# - Remove common page headers and footers from the Wikipedia pages.
# - Figure out what tags are the most common in Wikipedia pages.
# - Figure out patterns in the text.

# %%
wiki_list = ['wiki/'+el for el in os.listdir('wiki')]
print(len(wiki_list))

with open('wiki/Yarkant_County.html', encoding='UTF-8') as f:
    for line in f:
        print(line)
# Out:
# 999
# <!DOCTYPE html>
#
# <html class="client-nojs" lang="en" dir="ltr">
#
# <head>
#
# <meta charset="UTF-8"/>
#
# <title>Yarkant County - Wikipedia</title>
#
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
#
# <script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Yarkant_County","wgTitle":"Yarkant County","wgCurRevisionId":757597549,"wgRevisionId":757597549,"wgArticleId":879098,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Pages containing links to subscription-only content","Articles with Chinese-language external links","CS1 maint: Unrecognized language","Pages using ISBN magic links","Articles containing simplified Chinese-language text","Articles containing Uyghur-language text","Coordinates on Wikidata","Pages using infobox settlement with unknown parameters","Pages using deprecated coordinates format","Articles containing potentially dated statements from 2003","All articles containing potentially dated statements","Articles containing traditional Chinese-language text","All articles with unsourced statements","Articles with unsourced statements from August 2014","Articles that may contain original research from May 2016","Articles with unsourced statements from May 2016","Wikipedia articles with GND identifiers","Central Asian Buddhist kingdoms","Central Asian Buddhist sites","Populated places along the Silk Road","Populated places in Xinjiang","County-level divisions of Xinjiang","Oases of China","Ancient peoples of China","Former countries in Chinese history","Kashgar Prefecture"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"Yarkant_County","wgRelevantArticleId":879098,"wgRequestId":"WLmTNwpAIDoAAB74zVwAAABN","wgIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{}},"wgStableRevisionId":null,"wgWikiEditorEnabledModules":{"toolbar":true,"dialogs":true,"preview":false,"publish":false},"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsShouldSendModuleToUser":false,"wgPopupsConflictsWithNavPopupGadget":false,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","usePageImages":true,"usePageDescriptions":true},"wgPreferredVariant":"en","wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":true},"wgRelatedArticles":null,"wgRelatedArticlesBetaFeatureEnabled":false,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgCategoryTreePageCategoryOptions":"{\"mode\":0,\"hideprefix\":20,\"showcount\":true,\"namespaces\":false}","wgCoordinates":{"lat":38.416666666667,"lon":77.25},"wgWikibaseItemId":"Q857618","wgCentralAuthMobileDomain":false,"wgVisualEditorToolbarScrollOffset":0,"wgEditSubmitButtonLabelPublish":false});mw.loader.state({"ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","user":"ready","user.options":"loading","user.tokens":"loading","ext.cite.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.sectionAnchor":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready"});mw.loader.implement("user.options@0j3lz3q",function($,jQuery,require,module){mw.user.options.set({"vari ...
#
# mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});/*@nomin*/;
#
#
#
# });mw.loader.load(["ext.cite.a11y","mediawiki.toc","mediawiki.action.view.postEdit","site","mediawiki.page.startup","mediawiki.user","mediawiki.hidpi","mediawiki.page.ready","mediawiki.legacy.wikibits","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.gadget.featured-articles-links","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging.subscriber","ext.wikimediaEvents","ext.navigationTiming","ext.uls.eventlogger","ext.uls.init","ext.uls.interface","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"]);});</script>
#
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.sectionAnchor%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>
#
# <script async="" src="/w/load.php?debug=false&amp;lang=en&amp;modules=startup&amp;only=scripts&amp;skin=vector"></script>
#
# <meta name="ResourceLoaderDynamicStyles" content=""/>
#
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>
#
# <meta name="generator" content="MediaWiki 1.29.0-wmf.14"/>
#
# <meta name="referrer" content="origin-when-cross-origin"/>
#
# <meta property="og:image" content="https://upload.wikimedia.org/wikipedia/commons/9/93/Yarkand-calles-d01.jpg"/>
#
# <link rel="alternate" href="android-app://org.wikipedia/http/en.m.wikipedia.org/wiki/Yarkant_County"/>
#
# <link rel="alternate" type="application/x-wiki" title="Edit this page" href="/w/index.php?title=Yarkant_County&amp;action=edit"/>
#
# <link rel="edit" title="Edit this page" href="/w/index.php?title=Yarkant_County&amp;action=edit"/>
#
# <link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png"/>
#
# <link rel="shortcut icon" href="/static/favicon/wikipedia.ico"/>
#
# <link rel="search" type="application/opensearchdescription+xml" href="/w/opensearch_desc.php" title="Wikipedia (en)"/>
#
# <link rel="EditURI" type="application/rsd+xml" href="//en.wikipedia.org/w/api.php?action=rsd"/>
#
# <link rel="copyright" href="//creativecommons.org/licenses/by-sa/3.0/"/>
#
# <link rel="canonical" href="https://en.wikipedia.org/wiki/Yarkant_County"/>
#
# <link rel="dns-prefetch" href="//login.wikimedia.org"/>
#
# <link rel="dns-prefetch" href="//meta.wikimedia.org" />
#
# </head>
#
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-Yarkant_County rootpage-Yarkant_County skin-vector action-view">		<div id="mw-page-base" class="noprint"></div>
#
# 		<div id="mw-head-base" class="noprint"></div>
#
# 		<div id="content" class="mw-body" role="main">
#
# 			<a id="top"></a>
#
#
#
# 							<div id="siteNotice"><!-- CentralNotice --></div>
#
# 						<div class="mw-indicators">
#
# </div>
#
# 			<h1 id="firstHeading" class="firstHeading" lang="en">Yarkant County</h1>
#
# 									<div id="bodyContent" class="mw-body-content">
#
# 									<div id="siteSub">From Wikipedia, the free encyclopedia</div>
#
# 								<div id="contentSub"></div>
#
# 												<div id="jump-to-nav" class="mw-jump">
#
# 					Jump to:					<a href="#mw-head">navigation</a>, 					<a href="#p-search">search</a>
#
# 				</div>
#
# 				<div id="mw-content-text" lang="en" dir="ltr" class="mw-content-ltr"><table class="infobox geography vcard" style="width:22em;width:23em">
#
# <tr>
#
# <th colspan="2" style="text-align:center;font-size:125%;font-weight:bold;font-size:1.25em; white-space:nowrap"><span class="fn org"><span style="position:relative; bottom:0.2em;">Shache (Yarkant) County</span></span><br />
#
# <span class="nickname"><span style="position: relative; top: 0.1em;"><span style="font-weight:normal;"><span lang="zh-hans" xml:lang="zh-hans">莎车县</span> • <span lang="ug" xml:lang="ug">يەكەن ناھىيىسى</span></span></span></span></th>
#
# </tr>
#
# <tr>
#
# <td colspan="2" style="text-align:center;background-color:#cddeff; font-weight:bold;"><span class="category"><a href="/wiki/County_(People%27s_Republic_of_China)" class="mw-redirect" title="County (People's Republic of China)">County</a></span></td>
#
# </tr>
#
# <tr>
#
# <td colspan="2" style="text-align:center;padding:0.7em 0.8em"><a href="/wiki/File:Yarkand-calles-d01.jpg" class="image" title="A street in Yarkant"><img alt="A street in Yarkant" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/93/Yarkand-calles-d01.jpg/250px-Yarkand-calles-d01.jpg" width="250" height="188" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/93/Yarkand-calles-d01.jpg/375px-Yarkand-calles-d01.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/93/Yarkand-calles-d01.jpg/500px-Yarkand-calles-d01.jpg 2x" data-file-width="1024" data-file-height="768" /></a>
#
# <div>A street in Yarkant</div>
#
# </td>
#
# </tr>
#
# <tr class="mergedtoprow">
#
# <td colspan="2" style="text-align:center"><a href="/wiki/File:Location_of_Yarkand_within_Xinjiang_(China).png" class="image" title="Yarkant County (red) within Kashgar Prefecture (yellow) and Xinjiang"><img alt="Yarkant County (red) within Kashgar Prefecture (yellow) and Xinjiang" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/10/Location_of_Yarkand_within_Xinjiang_%28China%29.png/250px-Location_of_Yarkand_within_Xinjiang_%28China%29.png" width="250" height="190" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/10/Location_of_Yarkand_within_Xinjiang_%28China%29.png/375px-Location_of_Yarkand_within_Xinjiang_%28China%29.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/10/Location_of_Yarkand_within_Xinjiang_%28China%29.png/500px-Location_of_Yarkand_within_Xinjiang_%28China%29.png 2x" data-file-width="960" data-file-height="730" /></a><br />
#
# <small>Yarkant County (red) within Kashgar Prefecture (yellow) and Xinjiang</small></td>
#
# </tr>
#
# <tr class="mergedtoprow">
#
# <td colspan="2" style="text-align:center">
#
# <div class="center">
#
# <div style="width:250px;float:none;clear:both;margin-left:auto;margin-right:auto">
#
# <div style="width:250px;padding:0">
#
# <div style="position:relative;width:250px"><a href="/wiki/File:China_Xinjiang_location_map.svg" class="image" title="Yarkant is located in Xinjiang"><img alt="Yarkant is located in Xinjiang" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a5/China_Xinjiang_location_map.svg/250px-China_Xinjiang_location_map.svg.png" width="250" height="218" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/a5/China_Xinjiang_location_map.svg/375px-China_Xinjiang_location_map.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/a5/China_Xinjiang_location_map.svg/500px-China_Xinjiang_location_map.svg.png 2x" data-file-width="2220" data-file-height="1939" /></a>
#
# <div style="position:absolute;top:72.259%;left:17.234%">
#
# <div style="position:absolute;left:-3px;top:-3px;line-height:0"><img alt="Yarkant" src="//upload.wikimedia.org/wikipedia/en/thumb/0/0c/Red_pog.svg/6px-Red_pog.svg.png" title="Yarkant" width="6" height="6" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/0c/Red_pog.svg/9px-Red_pog.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/0c/Red_pog.svg/12px-Red_pog.svg.png 2x" data-file-width="64" data-file-height="64" /></div>
#
# <div style="font-size:90%;line-height:110%;position:absolute;width:6em;top:-0.75em;left:4px;text-align:left"><span style="padding:1px;float:left">Yarkant</span></div>
#
# </div>
#
# </div>
#
# </div>
#
# </div>
#
# </div>
#
# <small>Location in Xinjiang</small></td>
#
# </tr>
#
# <tr class="mergedbottomrow">
#
# <td colspan="2" style="text-align:center">Coordinates: <span style="white-space:nowrap"><span class="plainlinks nourlexpansion"><a class="external text" href="//tools.wmflabs.org/geohack/geohack.php?pagename=Yarkant_County&amp;params=38_25_N_77_15_E_type:adm3rd_region:CN-65"><span class="geo-default"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">38°25′N</span> <span class="longitude">77°15′E</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-nondefault"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">38.417°N 77.250°E</span><span style="display:none">﻿ / <span class="geo">38.417; 77.250</span></span></span></a></span><span style="font-size: small;"><span id="coordinates"><a href="/wiki/Geographic_coordinate_system" title="Geographic coordinate system">Coordinates</a>: <span class="plainlinks nourlexpansion"><a class="external text" href="//tools.wmflabs.org/geohack/geohack.php?pagename=Yarkant_County&amp;params=38_25_N_77_15_E_type:adm3rd_region:CN-65"><span class="geo-default"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">38°25′N</span> <span class="longitude">77°15′E</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-nondefault"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">38.417°N 77.250°E</span><span style="display:none">﻿ / <span class="geo">38.417; 77.250</span></span></span></a></span></span></span></span></td>
#
# </tr>
#
# <tr class="mergedtoprow">
#
# <th scope="row">Country</th>
#
# <td><a href="/wiki/China" title="China">China</a></td>
#
# </tr>
#
# <tr class="mergedrow">
#
# <th scope="row"><a href="/wiki/Autonomous_regions_of_the_People%27s_Republic_of_China" class="mw-redirect" title="Autonomous regions of the People's Republic of China">Region</a></th>
#
# <td><a href="/wiki/Xinjiang" title="Xinjiang">Xinjiang</a></td>
#
# </tr>
#
# <tr class="mergedrow">
#
# <th scope="row"><a href="/wiki/Prefecture_(China)" class="mw-redirect" title="Prefecture (China)">Prefecture</a></th>
#
# <td><a href="/wiki/Kashgar_Prefecture" title="Kashgar Prefecture">Kashgar</a></td>
#
# </tr>
#
# <tr class="mergedtoprow">
#
# <th colspan="2" style="text-align:center;text-align:left">Area</th>
#
# </tr>
#
# <tr class="mergedrow">
#
# <th scope="row">&#160;•&#160;Total</th>
#
# <td>8,969&#160;km<sup>2</sup> (3,463&#160;sq&#160;mi)</td>
#
# </tr>
#
# <tr class="mergedtoprow">
#
# <th scope="row">Elevation</th>
#
# <td>1,232&#160;m (4,042&#160;ft)</td>
#
# </tr>
#
# <tr class="mergedtoprow">
#
# <th colspan="2" style="text-align:center;text-align:left">Population <span style="font-weight:normal">(2002)</span></th>
#
# </tr>
#
# <tr class="mergedrow">
#
# <th scope="row">&#160;•&#160;Total</th>
#
# <td>650,000</td>
#
# </tr>
#
# <tr class="mergedrow">
#
# <th scope="row">&#160;•&#160;Density</th>
#
# <td>72/km<sup>2</sup> (190/sq&#160;mi)</td>
#
# </tr>
#
# <tr class="mergedtoprow">
#
# <th scope="row"><a href="/wiki/Time_zone" title="Time zone">Time zone</a></th>
#
# <td><a href="/wiki/China_Standard_Time" class="mw-redirect" title="China Standard Time">China Standard</a> (<a href="/wiki/UTC%2B8" class="mw-redirect" title="UTC+8">UTC+8</a>)</td>
#
# </tr>
#
# </table>
#
# <p><b>Shache (Yarkant) County</b> or <b>Yarkand County</b> (lit. <i>Cliff city</i><sup id="cite_ref-Y.C4.81rkand_1-0" class="reference"><a href="#cite_note-Y.C4.81rkand-1">[1]</a></sup>) is a county in the <a href="/wiki/Xinjiang_Uyghur_Autonomous_Region" class="mw-redirect" title="Xinjiang Uyghur Autonomous Region">Xinjiang Uyghur Autonomous Region</a>, <a href="/wiki/China" title="China">China</a>, located on the southern rim of the <a href="/wiki/Taklamakan" class="mw-redirect" title="Taklamakan">Taklamakan</a> desert in the <a href="/wiki/Tarim_Basin" title="Tarim Basin">Tarim Basin</a>. It is one of 11 counties administered under <a href="/wiki/Kashgar_Prefecture" title="Kashgar Prefecture">Kashgar Prefecture</a>. Yarkant, usually written <b>Yarkand</b> in English, was the seat of an ancient Buddhist kingdom on the southern branch of the <a href="/wiki/Silk_Road" title="Silk Road">Silk Road</a>. The county sits at an altitude of 1,189 metres (3,901&#160;ft) and as of 2003<sup class="plainlinks noprint asof-tag update" style="display:none;"><a class="external text" href="//en.wikipedia.org/w/index.php?title=Yarkant_County&amp;action=edit">[update]</a></sup> had a population of 373,492.</p>
#
# <p>The fertile <a href="/wiki/Oasis" title="Oasis">oasis</a> is fed by the <a href="/wiki/Yarkand_River" title="Yarkand River">Yarkand River</a> which flows north down from the Karakorum mountains and passes through <a href="/wiki/Kunlun_Mountains" title="Kunlun Mountains">Kunlun Mountains</a> known historically as <a href="/wiki/Congling" class="mw-redirect" title="Congling">Congling</a> mountains (lit. 'Onion Mountains' - from the abundance of wild onions found there). The oasis now covers 3,210 square kilometres (1,240&#160;sq&#160;mi), but was likely far more extensive before a period of <a href="/wiki/Desiccation" title="Desiccation">desiccation</a> affected the region from the 3rd century CE onwards.</p>
#
# <p>Today, Yarkant is a predominantly <a href="/wiki/Uyghur_people" class="mw-redirect" title="Uyghur people">Uyghur</a> settlement. The irrigated oasis farmland produces <a href="/wiki/Cotton" title="Cotton">cotton</a>, <a href="/wiki/Wheat" title="Wheat">wheat</a>, <a href="/wiki/Maize" title="Maize">corn</a>, fruits (especially <a href="/wiki/Pomegranates" class="mw-redirect" title="Pomegranates">pomegranates</a>, <a href="/wiki/Pear" title="Pear">pears</a> and <a href="/wiki/Apricots" class="mw-redirect" title="Apricots">apricots</a>), and walnuts. <a href="/wiki/Yak" class="mw-redirect" title="Yak">Yak</a> and sheep graze in the highlands. Mineral deposits include <a href="/wiki/Petroleum" title="Petroleum">petroleum</a>, <a href="/wiki/Natural_gas" title="Natural gas">natural gas</a>, <a href="/wiki/Gold" title="Gold">gold</a>, <a href="/wiki/Copper" title="Copper">copper</a>, <a href="/wiki/Lead" title="Lead">lead</a>, <a href="/wiki/Bauxite" title="Bauxite">bauxite</a>, <a href="/wiki/Granite" title="Granite">granite</a> and <a href="/wiki/Coal" title="Coal">coal</a>.</p>
#
# <table class="infobox" style="width: 22em">
#
# <tr>
#
# <td colspan="2" style="text-align:center;font-size: 125%; background-color: #b0c4de;">Yarkant County</td>
#
# </tr>
#
# <tr>
#
# <td colspan="2" style="text-align:center"><a href="/wiki/File:Street_scene_in_Yarkand_in_the_1870s.jpg" class="image"><img alt="Street scene in Yarkand in the 1870s.jpg" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Street_scene_in_Yarkand_in_the_1870s.jpg/240px-Street_scene_in_Yarkand_in_the_1870s.jpg" width="240" height="125" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Street_scene_in_Yarkand_in_the_1870s.jpg/360px-Street_scene_in_Yarkand_in_the_1870s.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Street_scene_in_Yarkand_in_the_1870s.jpg/480px-Street_scene_in_Yarkand_in_the_1870s.jpg 2x" data-file-width="1757" data-file-height="914" /></a>
#
# <div>Street scene in Yarkand in the 1870s</div>
#
# </td>
#
# </tr>
#
# <tr>
#
# <th colspan="2" style="text-align:center;background-color: #b0c4de;">Chinese name</th>
#
# </tr>
#
# <tr>
#
# <th scope="row" style="font-weight:normal;"><a href="/wiki/Traditional_Chinese_characters" title="Traditional Chinese characters">Traditional&#160;Chinese</a></th>
#
# <td><span style="font-size: 1rem"><span lang="zh-Hant" xml:lang="zh-Hant">莎車縣</span></span></td>
#
# </tr>
#
# <tr>
#
# <th scope="row" style="font-weight:normal;"><a href="/wiki/Simplified_Chinese_characters" title="Simplified Chinese characters">Simplified Chinese</a></th>
#
# <td><span style="font-size: 1rem"><span lang="zh-Hans" xml:lang="zh-Hans">莎车县</span></span></td>
#
# </tr>
#
# <tr>
#
# <td colspan="2" style="text-align:center">
#
# <table class="infobox collapsible collapsed" style="padding:0;border:none;margin:-3px;width:auto;min-width:100%;font-size:100%;clear:none;float:none;background-color:transparent">
#
# <tr>
#
# <th colspan="2" style="text-align:center;font-size:125%;font-weight:bold;font-size: 100%; text-align: left; background-color: #f9ffbc;">Transcriptions</th>
#
# </tr>
#
# <tr>
#
# <th colspan="2" style="text-align:center;background-color: #dcffc9;"><a href="/wiki/Standard_Chinese" title="Standard Chinese">Standard Mandarin</a></th>
#
# </tr>
#
# <tr>
#
# <th scope="row" style="font-weight:normal;"><a href="/wiki/Hanyu_Pinyin" class="mw-redirect" title="Hanyu Pinyin">Hanyu Pinyin</a></th>
#
# <td>Shāchē Xiàn</td>
#
# </tr>
#
# <tr>
#
# <th scope="row" style="font-weight:normal;"><a href="/wiki/Wade%E2%80%93Giles" title="Wade–Giles">Wade–Giles</a></th>
#
# <td>Sha1-ch'e1 Hsien4</td>
#
# </tr>
#
# <tr>
#
# <th scope="row" style="font-weight:normal;"><a href="/wiki/Wikipedia:IPA" class="mw-redirect" title="Wikipedia:IPA">IPA</a></th>
#
# <td><span class="IPA" style="white-space:nowrap"><a href="/wiki/Help:IPA_for_Mandarin" title="Help:IPA for Mandarin">[ʂáʈʂʰɤ́&#160;ɕjɛ̂n]</a></span></td>
#
# </tr>
#
# </table>
#
# </td>
#
# </tr>
#
# <tr>
#
# <th colspan="2" style="text-align:center;background-color: #b0c4de;">Uyghur name</th>
#
# </tr>
#
# <tr>
#
# <th scope="row" style="font-weight:normal;"><a href="/wiki/Uyghur_language" title="Uyghur language">Uyghur</a></th>
#
# <td>
#
# <div style="direction:rtl;"><span lang="ug" style="font-family:'UKIJ Tuz','UKIJ Nasq','UKIJ Basma','UKIJ_Mac Basma','UKIJ Zilwa','UKIJ Esliye','UKIJ Tuz Basma','UKIJ Tuz Kitab','UKIJ Tuz Gezit','UKIJ Tuz Qara','UKIJ Tuz Qara','UKIJ Tuz Tor','UKIJ Kesme','UKIJ Kesme Tuz','UKIJ Qara','UKIJ Basma Aq','UKIJ Basma Qara','UKIJ Basma Tuz','UKIJ Putuk','UKIJ Tuz Xet','UKIJ Tom Xet','UKIJ Tuz Jurnal','UKIJ Arabic','UKIJ CJK','UKIJ Ekran','UKIJ_Mac Ekran','UKIJ Teng','UKIJ Tor','UKIJ Tuz Tom','UKIJ Mono Keng','UKIJ Mono Tar','UKIJ Nokia','UKIJ SimSun','UKIJ Yanfon','UKIJ Qolyazma','UKIJ Saet','UKIJ Nasq Zilwa','UKIJ Sulus','UKIJ Sulus Tom','UKIJ 3D','UKIJ Diwani','UKIJ Diwani Yantu','UKIJ Diwani Tom','UKIJ Esliye Tom','UKIJ Esliye Qara','UKIJ Jelliy','UKIJ Kufi','UKIJ Kufi Tar','UKIJ Kufi Uz','UKIJ Kufi Yay','UKIJ Merdane','UKIJ Ruqi','UKIJ Mejnuntal','UKIJ Junun','UKIJ Moy Qelem','UKIJ Chiwer Kesme','UKIJ Orxun-Yensey','UKIJ Elipbe','UKIJ Qolyazma Tez','UKIJ Qolyazma Tuz','UKIJ Qolyazma Yantu','UKIJ Ruqi Tuz',FZWWBBOT_Unicode,FZWWHQHTOT_Unicode,'Microsoft Uighur'; font-size:135%;" xml:lang="ug">يەكەن ناھىيىسى</span></div>
#
# </td>
#
# </tr>
#
# <tr>
#
# <td colspan="2" style="text-align:center">
#
# <table class="infobox collapsible collapsed" style="padding:0;border:none;margin:-3px;width:auto;min-width:100%;font-size:100%;clear:none;float:none;background-color:transparent">
#
# <tr>
#
# <th colspan="2" style="text-align:center;font-size:125%;font-weight:bold;font-size: 100%; text-align: left; background-color: #f9ffbc;">Transcriptions</th>
#
# </tr>
#
# <tr>
#
# <th scope="row" style="font-weight:normal;"><a href="/wiki/Uyghur_Latin_alphabet" title="Uyghur Latin alphabet">Latin Yëziqi</a></th>
#
# <td>Yeken nahiyisi</td>
#
# </tr>
#
# <tr>
#
# <th scope="row" style="font-weight:normal;"><a href="/wiki/Uyghur_New_Script" title="Uyghur New Script">Yengi Yeziⱪ</a></th>
#
# <td>Yəkən nah̡iyisi</td>
#
# </tr>
#
# <tr>
#
# <th scope="row" style="font-weight:normal;"><a href="/wiki/SASM/GNC_romanization#Uyghur" title="SASM/GNC romanization">SASM/GNC</a></th>
#
# <td>Yarkant</td>
#
# </tr>
#
# <tr>
#
# <th scope="row" style="font-weight:normal;"><a href="/wiki/Uyghur_Cyrillic_alphabet" title="Uyghur Cyrillic alphabet">Siril Yëziqi</a></th>
#
# <td>Йәкән наһийиси</td>
#
# </tr>
#
# </table>
#
# </td>
#
# </tr>
#
# </table>
#
# <div class="thumb tright">
#
# <div class="thumbinner" style="width:262px;"><a href="/wiki/File:Tarimrivermap.png" class="image"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/7e/Tarimrivermap.png/260px-Tarimrivermap.png" width="260" height="177" class="thumbimage" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/7e/Tarimrivermap.png/390px-Tarimrivermap.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/7e/Tarimrivermap.png/520px-Tarimrivermap.png 2x" data-file-width="1467" data-file-height="1000" /></a>
#
# <div class="thumbcaption">
#
# <div class="magnify"><a href="/wiki/File:Tarimrivermap.png" class="internal" title="Enlarge"></a></div>
#
# Map showing the rivers of the <a href="/wiki/Tarim_Basin" title="Tarim Basin">Tarim Basin</a> and <a href="/wiki/Yarkand_River" title="Yarkand River">Yarkand River</a></div>
#
# </div>
#
# </div>
#
# <p></p>
#
# <div id="toc" class="toc">
#
# <div id="toctitle">
#
# <h2>Contents</h2>
#
# </div>
#
# <ul>
#
# <li class="toclevel-1 tocsection-1"><a href="#History"><span class="tocnumber">1</span> <span class="toctext">History</span></a>
#
# <ul>
#
# <li class="toclevel-2 tocsection-2"><a href="#Han_dynasty"><span class="tocnumber">1.1</span> <span class="toctext">Han dynasty</span></a></li>
#
# <li class="toclevel-2 tocsection-3"><a href="#Later_history"><span class="tocnumber">1.2</span> <span class="toctext">Later history</span></a></li>
#
# <li class="toclevel-2 tocsection-4"><a href="#Yarkent_Khanate"><span class="tocnumber">1.3</span> <span class="toctext">Yarkent Khanate</span></a></li>
#
# <li class="toclevel-2 tocsection-5"><a href="#Qing_dynasty"><span class="tocnumber">1.4</span> <span class="toctext">Qing dynasty</span></a></li>
#
# <li class="toclevel-2 tocsection-6"><a href="#Twentieth_century"><span class="tocnumber">1.5</span> <span class="toctext">Twentieth century</span></a></li>
#
# </ul>
#
# </li>
#
# <li class="toclevel-1 tocsection-7"><a href="#Geography"><span class="tocnumber">2</span> <span class="toctext">Geography</span></a>
#
# <ul>
#
# <li class="toclevel-2 tocsection-8"><a href="#Climate"><span class="tocnumber">2.1</span> <span class="toctext">Climate</span></a></li>
#
# </ul>
#
# </li>
#
# <li class="toclevel-1 tocsection-9"><a href="#Transportation"><span class="tocnumber">3</span> <span class="toctext">Transportation</span></a></li>
#
# <li class="toclevel-1 tocsection-10"><a href="#See_also"><span class="tocnumber">4</span> <span class="toctext">See also</span></a></li>
#
# <li class="toclevel-1 tocsection-11"><a href="#Footnotes"><span class="tocnumber">5</span> <span class="toctext">Footnotes</span></a></li>
#
# <li class="toclevel-1 tocsection-12"><a href="#References"><span class="tocnumber">6</span> <span class="toctext">References</span></a></li>
#
# <li class="toclevel-1 tocsection-13"><a href="#External_links"><span class="tocnumber">7</span> <span class="toctext">External links</span></a></li>
#
# </ul>
#
# </div>
#
# <p></p>
#
# <h2><span class="mw-headline" id="History">History</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Yarkant_County&amp;action=edit&amp;section=1" title="Edit section: History">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
#
# <h3><span class="mw-headline" id="Han_dynasty">Han dynasty</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Yarkant_County&amp;action=edit&amp;section=2" title="Edit section: Han dynasty">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
#
# <p>The territory of Yārkand is first mentioned in the <i><a href="/wiki/Book_of_Han" title="Book of Han">Book of Han</a></i> (1st century BCE) as "Shaju" (Old Chinese, approximately, *s³a(j)-ka), which is probably related to the name of the Iranian <a href="/wiki/Saka" title="Saka">Saka</a> tribes.<sup id="cite_ref-Y.C4.81rkand_1-1" class="reference"><a href="#cite_note-Y.C4.81rkand-1">[1]</a></sup></p>
#
# <p>Descriptions in the <i><a href="/wiki/Book_of_the_Later_Han" title="Book of the Later Han">Hou Hanshu</a></i> ('History of the Later Han') contain insights into the complex political situation China faced in attempting to open up the "Silk Routes" to the West in the 1st century CE. According to the "Chapter on the Western Regions" in the <i>Hou Hanshu</i>:</p>
#
# <dl>
#
# <dd>"Going west from the kingdom of Suoju (Yarkand), and passing through the countries of Puli (<a href="/wiki/Tashkurgan_Town" title="Tashkurgan Town">Tashkurghan</a>) and Wulei (centred on Sarhad in the <a href="/wiki/Wakhan" title="Wakhan">Wakhan</a>), you arrive among the <a href="/wiki/Da_Yuezhi" class="mw-redirect" title="Da Yuezhi">Da Yuezhi</a> (<a href="/wiki/Kushans" class="mw-redirect" title="Kushans">Kushans</a>). To the east, it is 10,950 li (4,553 km) from <a href="/wiki/Luoyang" title="Luoyang">Luoyang</a>.</dd>
#
# </dl>
#
# <dl>
#
# <dd>The Chanyu (Khan) of the <a href="/wiki/Xiongnu" title="Xiongnu">Xiongnu</a> took advantage of the chaos caused by <a href="/wiki/Wang_Mang" title="Wang Mang">Wang Mang</a> (9-24 CE) and invaded the Western Regions. Only Yan, the king of Suoju, who was more powerful than the others, did not consent to being annexed. Previously, during the time of <a href="/wiki/Emperor_Yuan_of_Han" title="Emperor Yuan of Han">Emperor Yuan</a> (48-33 BCE), he was a hostage prince and grew up in the capital. He admired and loved the Middle Kingdom and extended the rules of Chinese administration to his own country. He ordered all his sons to respectfully serve the Han dynasty generation by generation, and to never turn their backs on it. Yan died in the fifth Tianfeng year (18 CE). He was awarded the posthumous title of 'Faithful and Martial King'. His son, Kang, succeeded him on the throne.</dd>
#
# </dl>
#
# <dl>
#
# <dd>At the beginning of Emperor Guangwu's reign (25-57 CE), Kang led the neighbouring kingdoms to resist the Xiongnu. He escorted, and protected, more than a thousand people including the officers, the soldiers, the wife and children of the former Protector General. He sent a letter to <a href="/wiki/Hexi_Corridor" title="Hexi Corridor">Hexi</a> (Chinese territory west of the <a href="/wiki/Yellow_River" title="Yellow River">Yellow River</a>) to inquire about the activities of the Middle Kingdom, and personally expressed his attachment to, and admiration for, the Han dynasty.</dd>
#
# </dl>
#
# <dl>
#
# <dd>In the fifth Jianwu year (29 CE) the General-in-Chief of Hexi, Dou Rong, following Imperial instructions, bestowed on Kang the titles of: “King of Chinese Suoju, Performer of Heroic Deeds Who Cherishes Virtue [and] Commandant-in-Chief of the Western Regions.” The fifty-five kingdoms were all made dependencies after that.</dd>
#
# </dl>
#
# <dl>
#
# <dd>In the ninth year (33 CE) Kang died. He was awarded the posthumous title of “Greatly Accomplished King.” His younger brother, Xian, succeeded him on the throne. Xian attacked and conquered the kingdoms of Jumi (Keriya) and Xiye (Karghalik). He killed both their kings, and installed two sons of his elder brother, Kang, as the kings of Jumi and Xiye.</dd>
#
# </dl>
#
# <dl>
#
# <dd>In the fourteenth year (38 CE), together with An, the king of <a href="/wiki/Shanshan" title="Shanshan">Shanshan</a> (the <a href="/wiki/Lop_Nor" class="mw-redirect" title="Lop Nor">Lop Nor</a> region), he sent envoys to the Imperial Palace to offer tribute. Following this, the Western Regions were (again) in communication with China. All the kingdoms to the east of the Congling (Pamirs) were dependent on Xian.</dd>
#
# </dl>
#
# <dl>
#
# <dd>In the seventeenth year (41 CE), Xian again sent an envoy to present offerings [to the Emperor], and to ask that a Protector General be appointed. The Son of Heaven questioned the Excellency of Works, Dou Rong, about this. He was of the opinion that Xian, and his sons and brothers who had pledged to serve the Han were truly sincere. Therefore, [he suggested that] it would be appropriate to give him higher rank to maintain order and security.</dd>
#
# </dl>
#
# <div class="thumb tleft">
#
# <div class="thumbinner" style="width:172px;"><a href="/wiki/File:Yarkand_official.JPG" class="image"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Yarkand_official.JPG/170px-Yarkand_official.JPG" width="170" height="352" class="thumbimage" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Yarkand_official.JPG/255px-Yarkand_official.JPG 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Yarkand_official.JPG/340px-Yarkand_official.JPG 2x" data-file-width="634" data-file-height="1314" /></a>
#
# <div class="thumbcaption">
#
# <div class="magnify"><a href="/wiki/File:Yarkand_official.JPG" class="internal" title="Enlarge"></a></div>
#
# Yarkand official, 1870s</div>
#
# </div>
#
# </div>
#
# <dl>
#
# <dd>The Emperor then, using the same envoy that Xian had sent to him, bestowed upon him the seal and ribbon of “Protector General of the Western Regions,” and gave him chariots, standards, gold, brocades and embroideries.</dd>
#
# </dl>
#
# <p>"Pei Zun, the Administrator of <a href="/wiki/Dunhuang" title="Dunhuang">Dunhuang</a>, wrote saying that foreigners should not be allowed to employ such great authority and that these decrees would cause the kingdoms to despair. An Imperial decree then ordered that the seal and ribbons of “Protector General” be recovered, and replaced with the seal and ribbon of “Great Han General.” Xian’s envoy refused to make the exchange, and (Pei) Zun took them by force.</p>
#
# <dl>
#
# <dd>Consequently, Xian became resentful. Furthermore, he falsely named himself “Great Protector General,” and sent letters to all the kingdoms. They all submitted to him, and bestowed the title of Chanyu on him. Xian gradually became arrogant making heavy demands for duties and taxes. Several times he attacked Qiuci (<a href="/wiki/Kucha" title="Kucha">Kucha</a>) and the other kingdoms. All the kingdoms were anxious and fearful.</dd>
#
# </dl>
#
# <dl>
#
# <dd>In the winter of the twenty-first year (45 CE), eighteen kings, including the king of Nearer Jushi (<a href="/wiki/Turpan" title="Turpan">Turpan</a>), Shanshan, Yanqi (Karashahr), and others, sent their sons to enter the service of the Emperor and offered treasure. As a result, they were granted audience when they circulated weeping, prostrating with their foreheads to the ground, in the hope of obtaining a Protector General. The Son of Heaven, considering that the Middle Kingdom was just beginning to return to peace and that the northern frontier regions were still unsettled, returned all the hostage princes with generous gifts.</dd>
#
# </dl>
#
# <dl>
#
# <dd>At the same time, Xian, infatuated with his military power, wanted to annex the Western Regions, and greatly increased his attacks. The kingdoms, informed that no Protector General would be sent, and that the hostage princes were all returning, were very worried and frightened. Therefore, they sent a letter to the Administrator of Dunhuang to ask him to detain their hostage sons with him, so that they could point this out to the [king of] Suoju (Yarkand), and tell him that their young hostage sons were detained because a Protector General was to be sent. Then he [the king of Yarkand] would stop his hostilities. Pei Zun sent an official report informing the Emperor [of this proposal], which he approved.</dd>
#
# </dl>
#
# <dl>
#
# <dd>In the twenty-second year (46 CE Xian, aware that no Protector General was coming, sent a letter to An, king of Shanshan, ordering him to cut the route to the Han. An did not accept [this order], and killed the envoy. Xian was furious and sent soldiers to attack Shanshan. An gave battle but was defeated and fled into the mountains. Xian killed or captured more than a thousand men, and then withdrew.</dd>
#
# </dl>
#
# <dl>
#
# <dd>That winter (46 CE), Xian returned and attacked Qiuci (Kucha), killed the king, and annexed the kingdom. The hostage princes of Shanshan, and then Yanqi (Karashahr) and the other kingdoms, were detained a long time at Dunhuang and became worried, so they fled and returned [to their kingdoms].</dd>
#
# </dl>
#
# <dl>
#
# <dd>The king of Shanshan wrote a letter to the Emperor expressing his desire to return his son to enter the service of the Emperor, and again pleaded for a Protector General, saying that if a Protector General were not sent, he would be forced to obey the Xiongnu. The <a href="/wiki/Emperor_of_China" title="Emperor of China">Son of Heaven</a> replied:</dd>
#
# </dl>
#
# <dl>
#
# <dd>
#
# <dl>
#
# <dd>“We are not able, at the moment, to send out envoys and Imperial troops so, in spite of their good wishes, each kingdom [should seek help], as they please, wherever they can, to the east, west, south, or north.”</dd>
#
# </dl>
#
# </dd>
#
# </dl>
#
# <dl>
#
# <dd>Following this, Shanshan, and Jushi (Turpan/Jimasa) again submitted to the Xiongnu. Meanwhile, Xian became increasingly violent.</dd>
#
# </dl>
#
# <dl>
#
# <dd>The king of Guisai, reckoning that his kingdom was far enough away, killed Xian’s envoy. Xian then attacked and killed him. He appointed a nobleman from that country, Sijian, king of Guisai. Furthermore, Xian appointed his own son, Zeluo, to be king of Qiuci (Kucha). Xian, taking account of the youth of Zeluo, detached a part of the territory from Qiuci (Kucha) from which he made the kingdom of Wulei (Yengisar). He transferred Sijian to the post of king of Wulei, and appointed another noble to the post of king of Guisai.</dd>
#
# </dl>
#
# <dl>
#
# <dd>Several years later, the people of the kingdom of Qiuci (Kucha), killed Zeluo and Sijian, and sent envoys to the Xiongnu to ask them to appoint a king to replace them. The Xiongnu established a nobleman of Qiuci (Kucha), Shendu, to be king of Qiuci (Kucha), making it dependent on the Xiongnu.</dd>
#
# </dl>
#
# <dl>
#
# <dd>Because Dayuan (<a href="/wiki/Ferghana" class="mw-redirect" title="Ferghana">Ferghana</a>) had reduced their tribute and taxes, Xian personally took command of several tens of thousands of men taken from several kingdoms, and attacked Dayuan (Ferghana). Yanliu, the king of Dayuan, came before him to submit. Xian took advantage of this to take him back to his own kingdom. Then he transferred Qiaosaiti, the king of Jumi (Keriya), to the post of king of Dayuan (Ferghana). Then <a href="/wiki/Kangju" title="Kangju">Kangju</a> (Tashkent plus the Chu, Talas, and middle Jaxartes basins) attacked him there several times and Qiaosaiti fled home [to Keriya] more than a year later. Xian appointed him king of Jumi (Keriya) and sent Yanliu back to Dayuan again, ordering him to bring the customary tribute and offerings.</dd>
#
# </dl>
#
# <dl>
#
# <dd>Xian also banished the king of Yutian (<a href="/wiki/Khotan" class="mw-redirect" title="Khotan">Khotan</a>), Yulin, to be king of Ligui and set up his younger brother, Weishi, as king of Yutian.</dd>
#
# </dl>
#
# <dl>
#
# <dd>More than a year later Xian became suspicious that the kingdoms wanted to rebel against him. He summoned Weishi, and the kings of Jumi (Keriya), Gumo (Aksu), and Zihe (Shahidulla), and killed them all. He didn’t set up any more kings, he just sent generals to maintain order and guard these kingdoms. Rong, the son of Weishi, fled and made submission to the Han, who named him: “Marquis Who Maintains Virtue.” A general from Suoju (Yarkand), named Junde, had been posted to Yutian (Khotan), and tyrannised the people there who became indignant.</dd>
#
# </dl>
#
# <dl>
#
# <dd>In the third Yongping year (60 CE), during the reign of Emperor Ming, a high official of this country, called Dumo, had left town when he saw a wild pig. He wanted to shoot it, but the pig said to him: “Do not shoot me, I will undertake to kill Junde for you.” Following this, Dumo plotted with his brothers and killed Junde. However, another high official, Xiumo Ba, plotted, in his turn, with a Chinese man, Han Rong, and others, to kill Dumo and his brothers, then he named himself king of Yutian (Khotan). Together with men from the kingdom of Jumi (Keriya), he attacked and killed the Suoju (Yarkand) general who was at Pishan (modern Pishan or Guma). He then returned with the soldiers.</dd>
#
# </dl>
#
# <dl>
#
# <dd>Then Xian sent his Heir Apparent, and his State Chancellor, leading 20,000 soldiers from several kingdoms, to attack Xiumo Ba. [Xiumo] Ba came to meet them and gave battle, defeating the soldiers of Suoju (Yarkand) who fled, and more than 10,000 of them were killed.</dd>
#
# </dl>
#
# <dl>
#
# <dd>Xian again fielded several tens of thousands of men from several kingdoms, and personally led them to attack Xiumo Ba. [Xiumo] Ba was again victorious and beheaded more than half of the enemy. Xian escaped and fled, returning to his kingdom. Xiumo Ba advanced and encircled Suoju (Yarkand), but he was hit and killed by an arrow, and his soldiers retreated to Yutian (Khotan).</dd>
#
# </dl>
#
# <dl>
#
# <dd>Suyule, State Chancellor [of Khotan], and others, appointed Guangde, the son of Xiumo Ba’s elder brother, king. The <a href="/wiki/Xiongnu" title="Xiongnu">Xiongnu</a>, with Qiuci (Kucha) and the other kingdoms, attacked Suoju (Yarkand), but were unable to take it.</dd>
#
# </dl>
#
# <dl>
#
# <dd>Later, Guangde recognising of the exhaustion of Suoju (Yarkand), sent his younger brother, the Marquis who Supports the State, Ren, commanding an army, to attack Xian. As he had suffered war continuously, Xian sent an envoy to make peace with Guangde. Guangde's father had previously been detained for several years in Suoju (Yarkand). Xian returned Guangde's father and also gave one of his daughters in marriage and swore brotherhood to Guangde, so the soldiers withdrew and left.</dd>
#
# </dl>
#
# <div class="thumb tright">
#
# <div class="thumbinner" style="width:222px;"><a href="/wiki/File:Yarkand_Governor%27s_Guard.jpg" class="image"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Yarkand_Governor%27s_Guard.jpg/220px-Yarkand_Governor%27s_Guard.jpg" width="220" height="147" class="thumbimage" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Yarkand_Governor%27s_Guard.jpg/330px-Yarkand_Governor%27s_Guard.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Yarkand_Governor%27s_Guard.jpg/440px-Yarkand_Governor%27s_Guard.jpg 2x" data-file-width="1728" data-file-height="1157" /></a>
#
# <div class="thumbcaption">
#
# <div class="magnify"><a href="/wiki/File:Yarkand_Governor%27s_Guard.jpg" class="internal" title="Enlarge"></a></div>
#
# Andijani Taifurghis of the Yarkand Governor's Guard. 1870s</div>
#
# </div>
#
# </div>
#
# <dl>
#
# <dd>In the following year (61 CE), Qieyun, the Chancellor of Suoju (Yarkand), and others, worried by Xian's arrogance, plotted to get the town to submit to Yutian (Khotan). Guangde, the king of Yutian (Khotan), then led 30,000 men from several kingdoms to attack Suoju (Yarkand). Xian stayed in the town to defend it and sent a messenger to say to Guangde: “I have given you your father and a wife. Why are you attacking me?” Guangde replied to him: “O king, you are the father of my wife. It has been a long time since we met. I want us to meet, each of us escorted by only two men, outside the town wall to make an alliance.”</dd>
#
# </dl>
#
# <dl>
#
# <dd>Xian consulted Qieyun about this. Qieyun said to him: “Guangde, your son-in-law is a very close relation; you should go out to see him.” Xian then rashly went out. Guangde advanced and captured him. In addition, Qieyun and his colleagues let the soldiers of Yutian (Khotan) into the town to capture Xian’s wife and children. (Guangde) annexed his kingdom. He put Xian in chains, and took him home with him. More than a year later, he killed him.</dd>
#
# </dl>
#
# <dl>
#
# <dd>When the Xiongnu heard that Guangde had defeated Suoju (Yarkand), they sent five generals leading more than 30,000 men from fifteen kingdoms including Yanqi (Karashahr), Weili (Korla), and Qiuci (Kucha), to besiege Yutian (Khotan). Guangde asked to submit. He sent his Heir Apparent as a hostage and promised to give felt carpets each year. In winter, the Xiongnu ordered soldiers to take Xian’s son, Bujuzheng, who was a hostage with them, to appoint him king of Suoju (Yarkand).</dd>
#
# </dl>
#
# <dl>
#
# <dd>Guangde then attacked and killed [Bujuzheng], and put his younger brother, Qili, on the throne. This was in the third Yuanhe year (86 CE) of Emperor Zhang.</dd>
#
# </dl>
#
# <dl>
#
# <dd>At this time Chief Clerk Ban Chao brought the troops of several kingdoms to attack Suoju (Yarkand). He soundly defeated Suoju (Yarkand) so it submitted to Han."<sup id="cite_ref-2" class="reference"><a href="#cite_note-2">[2]</a></sup></dd>
#
# </dl>
#
# <p>In 90 CE the Yuezhi or Kushans invaded the region with an army of reportedly 70,000 men, under their Viceroy, Xian, but they were forced to withdraw without a battle after Ban Chao instigated a "burnt earth" policy.<sup id="cite_ref-3" class="reference"><a href="#cite_note-3">[3]</a></sup></p>
#
# <p>After the Yuanchu period (114-120 CE), when the <a href="/wiki/Yuezhi" title="Yuezhi">Yuezhi</a> or Kushans placed a hostage prince on the throne of Kashgar:</p>
#
# <dl>
#
# <dd>"...&#160;Suoju [Yarkand] followed by resisting Yutian [Khotan], and put themselves under Shule [Kashgar]. Thus Shule [Kashgar], became powerful and a rival to Qiuci [Kucha] and Yutian [Khotan]."<sup id="cite_ref-4" class="reference"><a href="#cite_note-4">[4]</a></sup></dd>
#
# </dl>
#
# <dl>
#
# <dd>"In the second Yongjian year [127 CE] of the reign of Emperor Shun, [Ban] Yong once again attacked and subdued Yanqi [Karashahr]; and then Qiuci [Kucha], Shule [Kashgar], Yutian [Khotan], Suoju [Yarkand], and other kingdoms, seventeen altogether, came to submit. Following this, the Wusun [Ili River Basin and Issyk Kul], and the countries of the Congling [Pamir Mountains], put an end to their disruptions to communications with the west."<sup id="cite_ref-5" class="reference"><a href="#cite_note-5">[5]</a></sup></dd>
#
# </dl>
#
# <p>In 130 CE, Yarkand, along with <a href="/wiki/Ferghana" class="mw-redirect" title="Ferghana">Ferghana</a> and <a href="/wiki/Kashgar" title="Kashgar">Kashgar</a>, sent tribute and offerings to the Chinese Emperor.<sup id="cite_ref-6" class="reference"><a href="#cite_note-6">[6]</a></sup></p>
#
# <h3><span class="mw-headline" id="Later_history">Later history</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Yarkant_County&amp;action=edit&amp;section=3" title="Edit section: Later history">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
#
# <div class="thumb tright">
#
# <div class="thumbinner" style="width:302px;"><a href="/wiki/File:Approach_to_Yarkand,_1868.jpg" class="image"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Approach_to_Yarkand%2C_1868.jpg/300px-Approach_to_Yarkand%2C_1868.jpg" width="300" height="218" class="thumbimage" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Approach_to_Yarkand%2C_1868.jpg/450px-Approach_to_Yarkand%2C_1868.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Approach_to_Yarkand%2C_1868.jpg/600px-Approach_to_Yarkand%2C_1868.jpg 2x" data-file-width="1269" data-file-height="924" /></a>
#
# <div class="thumbcaption">
#
# <div class="magnify"><a href="/wiki/File:Approach_to_Yarkand,_1868.jpg" class="internal" title="Enlarge"></a></div>
#
# Yarkand, 1868, showing city walls and gallows</div>
#
# </div>
#
# </div>
#
# <div class="thumb tright">
#
# <div class="thumbinner" style="width:222px;"><a href="/wiki/File:Yakka-Arik_Towers.jpg" class="image"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/44/Yakka-Arik_Towers.jpg/220px-Yakka-Arik_Towers.jpg" width="220" height="168" class="thumbimage" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/44/Yakka-Arik_Towers.jpg/330px-Yakka-Arik_Towers.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/44/Yakka-Arik_Towers.jpg/440px-Yakka-Arik_Towers.jpg 2x" data-file-width="482" data-file-height="368" /></a>
#
# <div class="thumbcaption">
#
# <div class="magnify"><a href="/wiki/File:Yakka-Arik_Towers.jpg" class="internal" title="Enlarge"></a></div>
#
# The towers in Yakka-Arik</div>
#
# </div>
#
# </div>
#
# ...
#
# 															<li  id="ca-talk"><span><a href="/wiki/Talk:Yarkant_County"  title="Discussion about the content page [t]" accesskey="t" rel="discussion">Talk</a></span></li>
#
# 													</ul>
#
# 					</div>
#
# 										<div id="p-variants" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-variants-label">
#
# 												<h3 id="p-variants-label">
#
# 							<span>Variants</span><a href="#"></a>
#
# 						</h3>
#
#
#
# 						<div class="menu">
#
# 							<ul>
#
# 															</ul>
#
# 						</div>
#
# 					</div>
#
# 									</div>
#
# 				<div id="right-navigation">
#
# 										<div id="p-views" role="navigation" class="vectorTabs" aria-labelledby="p-views-label">
#
# 						<h3 id="p-views-label">Views</h3>
#
# 						<ul>
#
# 															<li id="ca-view" class="selected"><span><a href="/wiki/Yarkant_County" >Read</a></span></li>
#
# 															<li id="ca-edit"><span><a href="/w/index.php?title=Yarkant_County&amp;action=edit"  title="Edit this page [e]" accesskey="e">Edit</a></span></li>
#
# 															<li id="ca-history" class="collapsible"><span><a href="/w/index.php?title=Yarkant_County&amp;action=history"  title="Past revisions of this page [h]" accesskey="h">View history</a></span></li>
#
# 													</ul>
#
# 					</div>
#
# 										<div id="p-cactions" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-cactions-label">
#
# 						<h3 id="p-cactions-label"><span>More</span><a href="#"></a></h3>
#
#
#
# 						<div class="menu">
#
# 							<ul>
#
# 															</ul>
#
# 						</div>
#
# 					</div>
#
# 										<div id="p-search" role="search">
#
# 						<h3>
#
# 							<label for="searchInput">Search</label>
#
# 						</h3>
#
#
#
# 						<form action="/w/index.php" id="searchform">
#
# 							<div id="simpleSearch">
#
# 							<input type="search" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" accesskey="f" id="searchInput"/><input type="hidden" value="Special:Search" name="title"/><input type="submit" name="fulltext" value="Search" title="Search Wikipedia for this text" id="mw-searchButton" class="searchButton mw-fallbackSearchButton"/><input type="submit" name="go" value="Go" title="Go to a page with this exact name if it exists" id="searchButton" class="searchButton"/>							</div>
#
# 						</form>
#
# 					</div>
#
# 									</div>
#
# 			</div>
#
# 			<div id="mw-panel">
#
# 				<div id="p-logo" role="banner"><a class="mw-wiki-logo" href="/wiki/Main_Page"  title="Visit the main page"></a></div>
#
# 						<div class="portal" role="navigation" id='p-navigation' aria-labelledby='p-navigation-label'>
#
# 			<h3 id='p-navigation-label'>Navigation</h3>
#
#
#
# 			<div class="body">
#
# 									<ul>
#
# 						<li id="n-mainpage-description"><a href="/wiki/Main_Page" title="Visit the main page [z]" accesskey="z">Main page</a></li><li id="n-contents"><a href="/wiki/Portal:Contents" title="Guides to browsing Wikipedia">Contents</a></li><li id="n-featuredcontent"><a href="/wiki/Portal:Featured_content" title="Featured content – the best of Wikipedia">Featured content</a></li><li id="n-currentevents"><a href="/wiki/Portal:Current_events" title="Find background information on current events">Current events</a></li><li id="n-randompage"><a href="/wiki/Special:Random" title="Load a random article [x]" accesskey="x">Random article</a></li><li id="n-sitesupport"><a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us">Donate to Wikipedia</a></li><li id="n-shoplink"><a href="//shop.wikimedia.org" title="Visit the Wikipedia store">Wikipedia store</a></li>					</ul>
#
# 							</div>
#
# 		</div>
#
# 			<div class="portal" role="navigation" id='p-interaction' aria-labelledby='p-interaction-label'>
#
# 			<h3 id='p-interaction-label'>Interaction</h3>
#
#
#
# 			<div class="body">
#
# 									<ul>
#
# 						<li id="n-help"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">Help</a></li><li id="n-aboutsite"><a href="/wiki/Wikipedia:About" title="Find out about Wikipedia">About Wikipedia</a></li><li id="n-portal"><a href="/wiki/Wikipedia:Community_portal" title="About the project, what you can do, where to find things">Community portal</a></li><li id="n-recentchanges"><a href="/wiki/Special:RecentChanges" title="A list of recent changes in the wiki [r]" accesskey="r">Recent changes</a></li><li id="n-contactpage"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">Contact page</a></li>					</ul>
#
# 							</div>
#
# 		</div>
#
# 			<div class="portal" role="navigation" id='p-tb' aria-labelledby='p-tb-label'>
#
# 			<h3 id='p-tb-label'>Tools</h3>
#
#
#
# 			<div class="body">
#
# 									<ul>
#
# 						<li id="t-whatlinkshere"><a href="/wiki/Special:WhatLinksHere/Yarkant_County" title="List of all English Wikipedia pages containing links to this page [j]" accesskey="j">What links here</a></li><li id="t-recentchangeslinked"><a href="/wiki/Special:RecentChangesLinked/Yarkant_County" rel="nofollow" title="Recent changes in pages linked from this page [k]" accesskey="k">Related changes</a></li><li id="t-upload"><a href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]" accesskey="u">Upload file</a></li><li id="t-specialpages"><a href="/wiki/Special:SpecialPages" title="A list of all special pages [q]" accesskey="q">Special pages</a></li><li id="t-permalink"><a href="/w/index.php?title=Yarkant_County&amp;oldid=757597549" title="Permanent link to this revision of the page">Permanent link</a></li><li id="t-info"><a href="/w/index.php?title=Yarkant_County&amp;action=info" title="More information about this page">Page information</a></li><li id="t-wikibase"><a href="https://www.wikidata.org/wiki/Q857618" title="Link to connected data repository item [g]" accesskey="g">Wikidata item</a></li><li id="t-cite"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=Yarkant_County&amp;id=757597549" title="Information on how to cite this page">Cite this page</a></li>					</ul>
#
# 							</div>
#
# 		</div>
#
# 			<div class="portal" role="navigation" id='p-coll-print_export' aria-labelledby='p-coll-print_export-label'>
#
# 			<h3 id='p-coll-print_export-label'>Print/export</h3>
#
#
#
# 			<div class="body">
#
# 									<ul>
#
# 						<li id="coll-create_a_book"><a href="/w/index.php?title=Special:Book&amp;bookcmd=book_creator&amp;referer=Yarkant+County">Create a book</a></li><li id="coll-download-as-rdf2latex"><a href="/w/index.php?title=Special:Book&amp;bookcmd=render_article&amp;arttitle=Yarkant+County&amp;returnto=Yarkant+County&amp;oldid=757597549&amp;writer=rdf2latex">Download as PDF</a></li><li id="t-print"><a href="/w/index.php?title=Yarkant_County&amp;printable=yes" title="Printable version of this page [p]" accesskey="p">Printable version</a></li>					</ul>
#
# 							</div>
#
# 		</div>
#
# 			<div class="portal" role="navigation" id='p-wikibase-otherprojects' aria-labelledby='p-wikibase-otherprojects-label'>
#
# 			<h3 id='p-wikibase-otherprojects-label'>In other projects</h3>
#
#
#
# 			<div class="body">
#
# 									<ul>
#
# 						<li class="wb-otherproject-link wb-otherproject-commons"><a href="https://commons.wikimedia.org/wiki/Category:Yarkand" hreflang="en">Wikimedia Commons</a></li><li class="wb-otherproject-link wb-otherproject-wikivoyage"><a href="https://en.wikivoyage.org/wiki/Yarkand" hreflang="en">Wikivoyage</a></li>					</ul>
#
# 							</div>
#
# 		</div>
#
# 			<div class="portal" role="navigation" id='p-lang' aria-labelledby='p-lang-label'>
#
# 			<h3 id='p-lang-label'>Languages</h3>
#
#
#
# 			<div class="body">
#
# 									<ul>
#
# 						<li class="interlanguage-link interwiki-ar"><a href="https://ar.wikipedia.org/wiki/%D9%8A%D8%A7%D8%B1%D9%83%D9%86%D8%AF" title="ياركند – Arabic" lang="ar" hreflang="ar" class="interlanguage-link-target">العربية</a></li><li class="interlanguage-link interwiki-az"><a href="https://az.wikipedia.org/wiki/Yark%C9%99nd" title="Yarkənd – Azerbaijani" lang="az" hreflang="az" class="interlanguage-link-target">Azərbaycanca</a></li><li class="interlanguage-link interwiki-ca"><a href="https://ca.wikipedia.org/wiki/Ciutat_de_Yarkand" title="Ciutat de Yarkand – Catalan" lang="ca" hreflang="ca" class="interlanguage-link-target">Català</a></li><li class="interlanguage-link interwiki-cs"><a href="https://cs.wikipedia.org/wiki/Jarkend" title="Jarkend – Czech" lang="cs" hreflang="cs" class="interlanguage-link-target">Čeština</a></li><li class="interlanguage-link interwiki-da"><a href="https://da.wikipedia.org/wiki/Soche" title="Soche – Danish" lang="da" hreflang="da" class="interlanguage-link-target">Dansk</a></li><li class="interlanguage-link interwiki-de"><a href="https://de.wikipedia.org/wiki/Yarkant" title="Yarkant – German" lang="de" hreflang="de" class="interlanguage-link-target">Deutsch</a></li><li class="interlanguage-link interwiki-fa"><a href="https://fa.wikipedia.org/wiki/%DB%8C%D8%A7%D8%B1%DA%A9%D9%86%D8%AF" title="یارکند – Persian" lang="fa" hreflang="fa" class="interlanguage-link-target">فارسی</a></li><li class="interlanguage-link interwiki-fr"><a href="https://fr.wikipedia.org/wiki/Xian_de_Yarkand" title="Xian de Yarkand – French" lang="fr" hreflang="fr" class="interlanguage-link-target">Français</a></li><li class="interlanguage-link interwiki-ko"><a href="https://ko.wikipedia.org/wiki/%EC%82%AC%EC%B2%98_%ED%98%84" title="사처 현 – Korean" lang="ko" hreflang="ko" class="interlanguage-link-target">한국어</a></li><li class="interlanguage-link interwiki-hi"><a href="https://hi.wikipedia.org/wiki/%E0%A4%AF%E0%A4%BE%E0%A4%B0%E0%A4%95%E0%A4%A8%E0%A5%8D%E0%A4%A6_%E0%A4%9C%E0%A4%BC%E0%A4%BF%E0%A4%B2%E0%A4%BE" title="यारकन्द ज़िला – Hindi" lang="hi" hreflang="hi" class="interlanguage-link-target">हिन्दी</a></li><li class="interlanguage-link interwiki-id"><a href="https://id.wikipedia.org/wiki/Yarkand" title="Yarkand – Indonesian" lang="id" hreflang="id" class="interlanguage-link-target">Bahasa Indonesia</a></li><li class="interlanguage-link interwiki-lt"><a href="https://lt.wikipedia.org/wiki/Jarkendas" title="Jarkendas – Lithuanian" lang="lt" hreflang="lt" class="interlanguage-link-target">Lietuvių</a></li><li class="interlanguage-link interwiki-nl"><a href="https://nl.wikipedia.org/wiki/Yarkand" title="Yarkand – Dutch" lang="nl" hreflang="nl" class="interlanguage-link-target">Nederlands</a></li><li class="interlanguage-link interwiki-ja"><a href="https://ja.wikipedia.org/wiki/%E3%83%A4%E3%83%AB%E3%82%AB%E3%83%B3%E3%83%89%E7%9C%8C" title="ヤルカンド県 – Japanese" lang="ja" hreflang="ja" class="interlanguage-link-target">日本語</a></li><li class="interlanguage-link interwiki-no"><a href="https://no.wikipedia.org/wiki/Yarkant" title="Yarkant – Norwegian" lang="no" hreflang="no" class="interlanguage-link-target">Norsk bokmål</a></li><li class="interlanguage-link interwiki-pnb"><a href="https://pnb.wikipedia.org/wiki/%DB%8C%D8%A7%D8%B1%D9%82%D9%86%D8%AF_%DA%A9%D8%A7%D8%A4%D9%86%D9%B9%DB%8C" title="یارقند کاؤنٹی – Western Punjabi" lang="pnb" hreflang="pnb" class="interlanguage-link-target">پنجابی</a></li><li class="interlanguage-link interwiki-pl"><a href="https://pl.wikipedia.org/wiki/Jarkend" title="Jarkend – Polish" lang="pl" hreflang="pl" class="interlanguage-link-target">Polski</a></li><li class="interlanguage-link interwiki-pt"><a href="https://pt.wikipedia.org/wiki/Iarcanda" title="Iarcanda – Portuguese" lang="pt" hreflang="pt" class="interlanguage-link-target">Português</a></li><li class="interlanguage-link interwiki-ru"><a href="https://ru.wikipedia.org/wiki/%D0%AF%D1%80%D0%BA%D0%B5%D0%BD%D0%B4" title="Яркенд – Russian" lang="ru" hreflang="ru" ...
#
# 				<div class='after-portlet after-portlet-lang'><span class="wb-langlinks-edit wb-langlinks-link"><a href="https://www.wikidata.org/wiki/Q857618#sitelinks-wikipedia" title="Edit interlanguage links" class="wbc-editpage">Edit links</a></span></div>			</div>
#
# 		</div>
#
# 				</div>
#
# 		</div>
#
# 		<div id="footer" role="contentinfo">
#
# 							<ul id="footer-info">
#
# 											<li id="footer-info-lastmod"> This page was last modified on 31 December 2016, at 16:15.</li>
#
# 											<li id="footer-info-copyright">Text is available under the <a rel="license" href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License">Creative Commons Attribution-ShareAlike License</a><a rel="license" href="//creativecommons.org/licenses/by-sa/3.0/" style="display:none;"></a>;
#
# additional terms may apply.  By using this site, you agree to the <a href="//wikimediafoundation.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//wikimediafoundation.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
#
# 									</ul>
#
# 							<ul id="footer-places">
#
# 											<li id="footer-places-privacy"><a href="https://wikimediafoundation.org/wiki/Privacy_policy" class="extiw" title="wmf:Privacy policy">Privacy policy</a></li>
#
# 											<li id="footer-places-about"><a href="/wiki/Wikipedia:About" title="Wikipedia:About">About Wikipedia</a></li>
#
# 											<li id="footer-places-disclaimer"><a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">Disclaimers</a></li>
#
# 											<li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
#
# 											<li id="footer-places-developers"><a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">Developers</a></li>
#
# 											<li id="footer-places-cookiestatement"><a href="https://wikimediafoundation.org/wiki/Cookie_statement">Cookie statement</a></li>
#
# 											<li id="footer-places-mobileview"><a href="//en.m.wikipedia.org/w/index.php?title=Yarkant_County&amp;mobileaction=toggle_view_mobile" class="noprint stopMobileRedirectToggle">Mobile view</a></li>
#
# 									</ul>
#
# 										<ul id="footer-icons" class="noprint">
#
# 											<li id="footer-copyrightico">
#
# 							<a href="https://wikimediafoundation.org/"><img src="/static/images/wikimedia-button.png" srcset="/static/images/wikimedia-button-1.5x.png 1.5x, /static/images/wikimedia-button-2x.png 2x" width="88" height="31" alt="Wikimedia Foundation"/></a>						</li>
#
# 											<li id="footer-poweredbyico">
#
# 							<a href="//www.mediawiki.org/"><img src="/static/images/poweredby_mediawiki_88x31.png" alt="Powered by MediaWiki" srcset="/static/images/poweredby_mediawiki_132x47.png 1.5x, /static/images/poweredby_mediawiki_176x62.png 2x" width="88" height="31"/></a>						</li>
#
# 									</ul>
#
# 						<div style="clear:both"></div>
#
# 		</div>
#
# 		<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.720","walltime":"0.851","ppvisitednodes":{"value":9669,"limit":1000000},"ppgeneratednodes":{"value":0,"limit":1500000},"postexpandincludesize":{"value":257297,"limit":2097152},"templateargumentsize":{"value":10447,"limit":2097152},"expansiondepth":{"value":25,"limit":40},"expensivefunctioncount":{"value":14,"limit":500},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00%  691.702      1 -total"," 48.18%  333.276      8 Template:Infobox"," 32.85%  227.196      1 Template:Infobox_settlement"," 18.57%  128.438      1 Template:Chinese"," 14.17%   98.032      1 Template:Reflist","  9.45%   65.346      1 Template:Infobox_Chinese/Chinese","  9.44%   65.303      1 Template:Weather_box","  4.97%   34.374      8 Template:Convert","  4.90%   33.861      8 Template:Category_handler","  4.41%   30.524      6 Template:Cite_book"]},"scribunto":{"limitreport-timeusage":{"value":"0.256","limit":"10.000"},"limitreport-memusage":{"value":7125809,"limit":52428800}},"cachereport":{"origin":"mw1188","timestamp":"20170303160056","ttl":2592000,"transientcontent":false}}});});</script><script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":935,"wgHostname":"mw1188"});});</script>
#
# 	</body>
#
# </html>

# %% [markdown]
# Now that we know the file structure, and the structure of a single file, we can read in all of the files. This will get us started in our explorations.

# %%
def full_content_list(file): #should return the content of a file
    with open(file) as f:
        return f.read()

start = time.time()
pool = concurrent.futures.ThreadPoolExecutor(max_workers=2)
content = pool.map(full_content_list, wiki_list)
content = list(content)

print(time.time() - start)
# print(content[1])

articles = [el.strip('wiki/''.html') for el in wiki_list]
print(articles[1]) #We've created a list that contains the article names
# Out:
# 0.3208339214324951
# Valentin_Yanin

# %% [markdown]
# We ran a series of experiments and found out that in this case threads with 2 workers give better speed in comparison with processes and threads with more than 2 workers. Approximately 0.2 seconds versus 0.5 seconds and 0.3 seconds, respectively.
#
#
# Now that we've read in the data files, we can remove the extraneous markup that's outside the div#content tag that most of the content seems to be inside. We can use the BeautifulSoup package for this. BeautifulSoup enables us to extract all of the content inside a specific tag.
#
# Using the BeautifulSoup package, we'll parse each wiki article, then extract the div with id content and everything inside it.

# %%
def content_list(file):
    soup = BeautifulSoup(file, 'html.parser')
    return str(soup.find_all("div", id="content")[0])

start = time.time()
pool = concurrent.futures.ProcessPoolExecutor(max_workers=2)
parsed = pool.map(content_list, content)
parsed = list(parsed)

print(time.time() - start)
print(parsed[1])
# Out:
# 27.389646291732788
# <div class="mw-body" id="content" role="main">
# <a id="top"></a>
# <div id="siteNotice"><!-- CentralNotice --></div>
# <div class="mw-indicators">
# </div>
# <h1 class="firstHeading" id="firstHeading" lang="en">Valentin Yanin</h1>
# <div class="mw-body-content" id="bodyContent">
# <div id="siteSub">From Wikipedia, the free encyclopedia</div>
# <div id="contentSub"></div>
# <div class="mw-jump" id="jump-to-nav">
# 					Jump to:					<a href="#mw-head">navigation</a>, 					<a href="#p-search">search</a>
# </div>
# <div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="en"><p><b>Valentin Lavrentievich Yanin</b> (<a href="/wiki/Russian_language" title="Russian language">Russian</a>: <span lang="ru" xml:lang="ru">Валентин Лаврентьевич Янин</span>, born 6 February 1929 in <a href="/wiki/Kirov,_Kirov_Oblast" title="Kirov, Kirov Oblast">Vyatka</a>) is a leading <a href="/wiki/Russia" title="Russia">Russian</a> historian who has authored 700 books and articles. He has also edited a number of important journals and primary sources, including works on medieval Russian law, <a class="mw-redirect" href="/wiki/Sphragistics" title="Sphragistics">sphragistics</a> and <a href="/wiki/Epigraphy" title="Epigraphy">epigraphy</a>, <a href="/wiki/Archaeology" title="Archaeology">archaeology</a> and history. His expertise is medieval Rus' especially <a class="mw-redirect" href="/wiki/Novgorod_the_Great" title="Novgorod the Great">Novgorod the Great</a>, where he has headed archaeological digs beginning in 1962.</p>
# <p></p>
# <div class="toc" id="toc">
# <div id="toctitle">
# <h2>Contents</h2>
# </div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#Early_life"><span class="tocnumber">1</span> <span class="toctext">Early life</span></a></li>
# <li class="toclevel-1 tocsection-2"><a href="#Research"><span class="tocnumber">2</span> <span class="toctext">Research</span></a></li>
# <li class="toclevel-1 tocsection-3"><a href="#Honours_and_Positions"><span class="tocnumber">3</span> <span class="toctext">Honours and Positions</span></a></li>
# <li class="toclevel-1 tocsection-4"><a href="#References"><span class="tocnumber">4</span> <span class="toctext">References</span></a></li>
# </ul>
# </div>
# <p></p>
# <h2><span class="mw-headline" id="Early_life">Early life</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Valentin_Yanin&amp;action=edit&amp;section=1" title="Edit section: Early life">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>His maternal grandparents were arrested in 1937 and died in a prison camp in 1938. His father was apparently on a list to be executed but escaped this fate and moved with his family to Moscow.<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup> Yanin finished his secondary education in 1946, graduating with a Gold Medal; he matriculated at <a href="/wiki/Moscow_State_University" title="Moscow State University">Moscow State University</a> in 1951.</p>
# <h2><span class="mw-headline" id="Research">Research</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Valentin_Yanin&amp;action=edit&amp;section=2" title="Edit section: Research">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>In 1954, he defended his <a class="mw-redirect" href="/wiki/Kandidat" title="Kandidat">Kandidat</a> thesis on the <a href="/wiki/Monetary_system" title="Monetary system">monetary systems</a> of pre-Mongol Rus. This was published as <i>The Monetary and Weight System of Medieval Russia</i> ("Денежно-весовые системы русского средневековья") and has become a classic. His doctoral thesis on the <a href="/wiki/Posadnik" title="Posadnik">posadniks</a> of <a class="mw-redirect" href="/wiki/Novgorod" title="Novgorod">Novgorod</a> followed in 1962 and significantly changed our understanding of the constitution of the <a href="/wiki/Novgorod_Republic" title="Novgorod Republic">Novgorod Republic</a>.<sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup> The book demonstrated that the office of posadnik, while subject to election every year, was often held by one man for several consecutive years, sometimes more than a decade, and then passed on to his sons or other members of his clan. It shattered the earlier image of Novgorod as a more democratic republic and showed it to be ruled by a boyar aristocracy (not unlike other medieval republics).</p>
# <p>Yanin's monograph about the seals of Ancient Rus (2 volumes, 1970) summed up half a century of Soviet sphragistics research. After that, Yanin turned his attention to the <a class="mw-redirect" href="/wiki/Birch_bark_document" title="Birch bark document">birch bark documents</a> of <a class="mw-redirect" href="/wiki/Novgorod" title="Novgorod">Novgorod</a>, on which he is considered the greatest living authority (alongside <a href="/wiki/Andrey_Zaliznyak" title="Andrey Zaliznyak">Andrey Zaliznyak</a>).</p>
# <h2><span class="mw-headline" id="Honours_and_Positions">Honours and Positions</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Valentin_Yanin&amp;action=edit&amp;section=3" title="Edit section: Honours and Positions">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>In 1964, Yanin became professor in the department of archaeology in the Faculty of History at <a href="/wiki/Moscow_State_University" title="Moscow State University">Moscow State University</a>.</p>
# <p>Since 1978, Yanin has held the chair in archaeology at the Moscow University.</p>
# <p>He is a member of the President's Committee for the Defence of the Material Culture of the Russian Federation and a member of the Consultative Committee of the Ministry of Culture of the Russian Federation.</p>
# <p>In 1962, he was elected a corresponding member of the <a class="mw-redirect" href="/wiki/Soviet_Academy_of_Sciences" title="Soviet Academy of Sciences">Soviet Academy of Sciences</a>; he became a full academician in 1990. In 1999, he became the first historian to be awarded the <a href="/wiki/Lomonosov_Gold_Medal" title="Lomonosov Gold Medal">Lomonosov Gold Medal</a>.</p>
# <p>His other awards include:</p>
# <ul>
# <li><a class="mw-redirect" href="/wiki/Order_of_Merit_for_the_Fatherland" title="Order of Merit for the Fatherland">Order of Merit for the Fatherland 4th class</a></li>
# <li><a href="/wiki/Order_of_Lenin" title="Order of Lenin">Order of Lenin</a></li>
# <li><a href="/wiki/Order_of_the_Red_Banner_of_Labour" title="Order of the Red Banner of Labour">Order of the Red Banner of Labour</a></li>
# <li><a href="/wiki/Order_of_Friendship_of_Peoples" title="Order of Friendship of Peoples">Order of Friendship of Peoples</a></li>
# <li><a href="/wiki/Medal_%22Veteran_of_Labour%22" title='Medal "Veteran of Labour"'>Medal "Veteran of Labour"</a></li>
# <li><a href="/wiki/USSR_State_Prize" title="USSR State Prize">USSR State Prize</a> (1970)</li>
# <li><a href="/wiki/Lenin_Prize" title="Lenin Prize">Lenin Prize</a> (1984)</li>
# <li><a href="/wiki/Demidov_Prize" title="Demidov Prize">Demidov Prize</a> (1993)</li>
# <li>State Prize of the Russian Federation (1996)</li>
# <li>Triumph Prize (2002)</li>
# <li><a href="/wiki/Solzhenitsyn_Prize" title="Solzhenitsyn Prize">Solzhenitsyn Prize</a> (2010).</li>
# </ul>
# <p>He is an honorary citizen of Novgorod the Great and an honorary member of the Novgorodian Society of Lovers of Antiquities.<sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup></p>
# <h2><span class="mw-headline" id="References">References</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Valentin_Yanin&amp;action=edit&amp;section=4" title="Edit section: References">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <div class="reflist" style="list-style-type: decimal;">
# <ol class="references">
# <li id="cite_note-1"><span class="mw-cite-backlink"><b><a href="#cite_ref-1">^</a></b></span> <span class="reference-text"><a class="external free" href="http://www.whoiswho.ru/russian/Password/journals/11999/yaninr1.htm" rel="nofollow">http://www.whoiswho.ru/russian/Password/journals/11999/yaninr1.htm</a></span></li>
# <li id="cite_note-2"><span class="mw-cite-backlink"><b><a href="#cite_ref-2">^</a></b></span> <span class="reference-text">V. L. Yanin, <i>Novgorodskie Posadniki</i> (Moscow: Moscow State University, 1962; reprinted Moscow: Iazyki slavianskoi kul'tury, 2003).</span></li>
# <li id="cite_note-3"><span class="mw-cite-backlink"><b><a href="#cite_ref-3">^</a></b></span> <span class="reference-text">See Yanin's biography at MGU: <a class="external free" href="http://www.hist.msu.ru/Departments/Arch/Staff/Yanin.htm" rel="nofollow">http://www.hist.msu.ru/Departments/Arch/Staff/Yanin.htm</a></span></li>
# </ol>
# </div>
# <div aria-label="Navbox" class="navbox" role="navigation" style="padding:3px">
# <table class="nowraplinks hlist navbox-inner" style="border-spacing:0;background:transparent;color:inherit">
# <tr>
# <th class="navbox-group" scope="row"><a href="/wiki/Help:Authority_control" title="Help:Authority control">Authority control</a></th>
# <td class="navbox-list navbox-odd" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px">
# <div style="padding:0em 0.25em">
# <ul>
# <li><span style="white-space:nowrap;"><a class="external text" href="//www.worldcat.org/identities/containsVIAFID/45138852" rel="nofollow">WorldCat Identities</a></span></li>
# <li><span style="white-space:nowrap;"><a href="/wiki/Virtual_International_Authority_File" title="Virtual International Authority File">VIAF</a>: <span class="uid"><a class="external text" href="https://viaf.org/viaf/45138852" rel="nofollow">45138852</a></span></span></li>
# <li><span style="white-space:nowrap;"><a href="/wiki/Library_of_Congress_Control_Number" title="Library of Congress Control Number">LCCN</a>: <span class="uid"><a class="external text" href="http://id.loc.gov/authorities/names/n81115419" rel="nofollow">n81115419</a></span></span></li>
# <li><span style="white-space:nowrap;"><a href="/wiki/Syst%C3%A8me_universitaire_de_documentation" title="Système universitaire de documentation">SUDOC</a>: <span class="uid"><a class="external text" href="https://www.idref.fr/061644455" rel="nofollow">061644455</a></span></span></li>
# <li><span style="white-space:nowrap;"><a href="/wiki/Biblioth%C3%A8que_nationale_de_France" title="Bibliothèque nationale de France">BNF</a>: <span class="uid"><a class="external text" href="http://catalogue.bnf.fr/ark:/12148/cb120449899" rel="nofollow">cb120449899</a> <a class="external text" href="http://data.bnf.fr/ark:/12148/cb120449899" rel="nofollow">(data)</a></span></span></li>
# </ul>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <!--
# NewPP limit report
# Parsed by mw1262
# Cached time: 20170228003833
# Cache expiry: 2592000
# Dynamic content: false
# CPU time usage: 0.060 seconds
# Real time usage: 0.084 seconds
# Preprocessor visited node count: 219/1000000
# Preprocessor generated node count: 0/1500000
# Post‐expand include size: 3742/2097152 bytes
# Template argument size: 183/2097152 bytes
# Highest expansion depth: 12/40
# Expensive parser function count: 2/500
# Lua time usage: 0.027/10.000 seconds
# Lua memory usage: 949 KB/50 MB
# -->
# <!--
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%   68.380      1 -total
#  49.21%   33.650      1 Template:Lang-ru
#  47.12%   32.221      1 Template:Language_with_name_and_transliteration
#  44.21%   30.231      1 Template:Lang
#  42.81%   29.272      1 Template:Authority_control
#  40.86%   27.942      1 Template:Category_handler
#   4.72%    3.230      1 Template:Reflist
#   2.57%    1.755      2 Template:ISO_639_name
#   0.95%    0.652      2 Template:ISO_639_name_ru
# -->
# <!-- Saved in parser cache with key enwiki:pcache:idhash:7502081-0!*!0!!en!*!* and timestamp 20170228003833 and revision id 736718079
#  -->
# <noscript><img alt="" height="1" src="//en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1" style="border: none; position: absolute;" title="" width="1"/></noscript></div> <div class="printfooter">
# 						Retrieved from "<a dir="ltr" href="https://en.wikipedia.org/w/index.php?title=Valentin_Yanin&amp;oldid=736718079">https://en.wikipedia.org/w/index.php?title=Valentin_Yanin&amp;oldid=736718079</a>"					</div>
# <div class="catlinks" data-mw="interface" id="catlinks"><div class="mw-normal-catlinks" id="mw-normal-catlinks"><a href="/wiki/Help:Category" title="Help:Category">Categories</a>: <ul><li><a href="/wiki/Category:Living_people" title="Category:Living people">Living people</a></li><li><a href="/wiki/Category:1929_births" title="Category:1929 births">1929 births</a></li><li><a href="/wiki/Category:Russian_historians" title="Category:Russian historians">Russian historians</a></li><li><a href="/wiki/Category:Soviet_historians" title="Category:Soviet historians">Soviet historians</a></li><li><a href="/wiki/Category:20th-century_historians" title="Category:20th-century historians">20th-century historians</a></li><li><a href="/wiki/Category:Russian_archaeologists" title="Category:Russian archaeologists">Russian archaeologists</a></li><li><a href="/wiki/Category:Soviet_archaeologists" title="Category:Soviet archaeologists">Soviet archaeologists</a></li><li><a href="/wiki/Category:Moscow_State_University_alumni" title="Category:Moscow State University alumni">Moscow State University alumni</a></li><li><a href="/wiki/Category:Moscow_State_University_faculty" title="Category:Moscow State University faculty">Moscow State University faculty</a></li><li><a href="/wiki/Category:Historians_of_Russia" title="Category:Historians of Russia">Historians of Russia</a></li><li><a href="/wiki/Category:Full_Members_of_the_USSR_Academy_of_Sciences" title="Category:Full Members of the USSR Academy of Sciences">Full Members of the USSR Academy of Sciences</a></li><li><a href="/wiki/Category:Full_Members_of_the_Russian_Academy_of_Sciences" title="Category:Full Members of the Russian Academy of Sciences">Full Members of the Russian Academy of Sciences</a></li><li><a href="/wiki/Category:Demidov_Prize_laureates" title="Category:Demidov Prize laureates">Demidov Prize laureates</a></li><li><a href="/wiki/Category:Solzhenitsyn_Prize_winners" title="Category:Solzhenitsyn Prize winners">Solzhenitsyn Prize winners</a></li><li><a href="/wiki/Category:Lenin_Prize_winners" title="Category:Lenin Prize winners">Lenin Prize winners</a></li><li><a href="/wiki/Category:Recipients_of_the_USSR_State_Prize" title="Category:Recipients of the USSR State Prize">Recipients of the USSR State Prize</a></li><li><a href="/wiki/Category:Recipients_of_the_Lomonosov_Gold_Medal" title="Category:Recipients of the Lomonosov Gold Medal">Recipients of the Lomonosov Gold Medal</a></li><li><a href="/wiki/Category:Recipients_of_the_Order_of_Lenin" title="Category:Recipients of the Order of Lenin">Recipients of the Order of Lenin</a></li><li><a href="/wiki/Category:Recipients_of_the_Order_of_the_Red_Banner_of_Labour" title="Category:Recipients of the Order of the Red Banner of Labour">Recipients of the Order of the Red Banner of Labour</a></li><li><a href="/wiki/Category:Recipients_of_the_Order_%22For_Merit_to_the_Fatherland%22,_4th_class" title='Category:Recipients of the Order "For Merit to the Fatherland", 4th class'>Recipients of the Order "For Merit to the Fatherland", 4th class</a></li></ul></div><div class="mw-hidden-catlinks mw-hidden-cats-hidden" id="mw-hidden-catlinks">Hidden categories: <ul><li><a href="/wiki/Category:Articles_containing_Russian-language_text" title="Category:Articles containing Russian-language text">Articles containing Russian-language text</a></li><li><a href="/wiki/Category:Wikipedia_articles_with_VIAF_identifiers" title="Category:Wikipedia articles with VIAF identifiers">Wikipedia articles with VIAF identifiers</a></li><li><a href="/wiki/Category:Wikipedia_articles_with_LCCN_identifiers" title="Category:Wikipedia articles with LCCN identifiers">Wikipedia articles with LCCN identifiers</a></li><li><a href="/wiki/Category:Wikipedia_articles_with_BNF_identifiers" title="Category:Wikipedia articles with BNF identifiers">Wikipedia articles with BNF identifiers</a></li></ul></div></div> <div class="visualClear"></div>
# </div>
# </div>

# %% [markdown]
# This operation is quite slow and requires significant CPU resources. It looks like using as many available processors as possible doesn't speed things up very much.

# %%
def count_tags(html):
    soup = BeautifulSoup(html, 'html.parser')
    tags = {}
    for tag in soup.find_all():
        tags[tag.name] = tags.get(tag.name, 0) + 1
    return tags

start = time.time()
pool = concurrent.futures.ProcessPoolExecutor(max_workers=2)
tags_list = pool.map(count_tags, parsed)
tags_list = list(tags_list)

tags = {}
for dict_ in tags_list:
    for key in dict_:
        tags[key] = tags.get(key, 0) + dict_[key]

print(time.time() - start)
print(tags)
# Out:
# 13.833491802215576
# {'b': 14455, 'sup': 11157, 'sub': 151, 'blockquote': 58, 'a': 161065, 'li': 85779, 'tr': 27300, 'img': 6701, 'br': 4986, 'wbr': 85, 'h6': 1, 'p': 7998, 'ol': 858, 'mstyle': 2, 'hr': 51, 'div': 28581, 'math': 2, 'annotation': 2, 'big': 75, 'caption': 200, 's': 10, 'semantics': 2, 'dd': 1376, 'del': 2, 'table': 4010, 'samp': 2, 'rb': 16, 'span': 67350, 'dt': 334, 'ul': 10972, 'h4': 117, 'noscript': 999, 'q': 76, 'small': 3272, 'mrow': 2, 'dl': 457, 'h1': 999, 'center': 64, 'u': 51, 'pre': 1, 'audio': 2, 'map': 2, 'rp': 32, 'source': 2, 'th': 14472, 'ruby': 16, 'cite': 3563, 'i': 18246, 'bdi': 4, 'mo': 2, 'h2': 4045, 'area': 39, 'font': 40, 'h3': 777, 'abbr': 3665, 'h5': 4, 'td': 57673, 'code': 108, 'rt': 16, 'strong': 599}

# %% [markdown]
# We ran a series of experiments and found out that in this case processes with 2 workers give better speed in comparison with threads. Approximately 13 seconds versus 27 seconds respectively.
#
#
#
# For now, let's find the most frequently used words in all files. Only words longer than 5 characters will be counted.

# %%
def word_counter(html): 
    soup = BeautifulSoup(html, 'html.parser')
    words = {}
    text = soup.get_text()
    text = text.lower()
    text = re.findall("\w{5,}", text)
#     text = text.split(" ")
#     text = [w for w in text if len(w) >= 5]
    words = {}
    for word in text:
        words[word] = words.get(word, 0) + 1
    return words

start = time.time()
pool = concurrent.futures.ProcessPoolExecutor(max_workers=2)
words_list = pool.map(word_counter, parsed)
words_list = list(words_list)

words = {}
for dict_ in words_list:
    for key in dict_:
        words[key] = words.get(key, 0) + dict_[key]

print(time.time() - start)
words
# Out:
# 14.15831470489502
# {'kingdombuildings': 1,
#  '67461': 1,
#  '757428306': 1,
#  'empireknights': 1,
#  'motto': 13,
#  '761408194': 1,
#  'пушкина': 1,
#  '768381931': 1,
#  'additionally': 9,
#  'carbonell': 1,
#  'optioned': 2,
#  'pietro': 7,
#  'tripiṭaka': 2,
#  'avogadro': 1,
#  'busca': 1,
#  'nubicus': 1,
#  'tuždimъ': 1,
#  'reappears': 2,
#  'intequam': 1,
#  'reviewer': 4,
#  'gulbenkian': 1,
#  'taungbyu': 1,
#  'bentley': 8,
#  'planners': 1,
#  'talesh': 2,
#  'wetpaint': 1,
#  'curtain': 2,
#  'stovsky': 1,
#  'zhejiang': 11,
#  'kriss': 1,
#  'rencontre': 1,
#  'pratincola': 1,
#  'posidonia': 3,
#  '2015pages': 2,
#  'playerss': 4,
#  'yeldon': 1,
#  'okehampton': 1,
#  'crandon': 1,
#  'hardly': 3,
#  'nargestan': 1,
#  'skinnigrove': 1,
#  'korchvandan': 1,
#  'shipley': 1,
#  'gurudarshan': 1,
#  'aggression': 3,
#  'jharsuguda': 2,
#  'renera': 1,
#  'saskia': 1,
#  'valdenuño': 1,
#  'expectations': 9,
#  '42028': 2,
#  'poses': 1,
#  'maisons': 2,
#  'reviewed': 5,
#  'n81009469': 1,
#  'северная': 1,
#  'strassburg': 1,
#  'amazonaws': 1,
#  'ottavio': 1,
#  'finland1993': 1,
#  'bærum': 1,
#  'fadak': 2,
#  '709586411': 1,
#  'orleans': 31,
#  'dimanno': 1,
#  'ceased': 18,
#  'mezzeh': 1,
#  'isovaleryl': 1,
#  'californiamountains': 1,
#  'torneo': 12,
#  'cortés': 1,
#  'torjussen': 1,
#  '34842073t': 1,
#  'chelveston': 2,
#  'brash': 3,
#  'leonora': 1,
#  'gormsen': 1,
#  'kozienice': 4,
#  'genuine': 4,
#  'yorkhidden': 4,
#  'badmovies': 1,
#  'tabestan': 1,
#  'perciform': 1,
#  'sandy': 25,
#  'pugachev': 1,
#  'bains': 6,
#  'batagay': 1,
#  'brighter': 1,
#  'shaping': 5,
#  'tulafono': 1,
#  'lanceolata': 1,
#  'allured': 2,
#  'dartford': 8,
#  'définition': 1,
#  'darkens': 1,
#  'anagadi': 1,
#  'godhra': 1,
#  'tomans': 1,
#  'shedbal': 1,
#  'bloodbrothers': 1,
#  '30589': 1,
#  'tracts': 4,
#  'alessandra': 2,
#  '765957819': 1,
#  'unknownplace': 1,
#  'sogdian': 2,
#  'drummondvilleatp': 1,
#  'galeazzo': 1,
#  'identifiable': 1,
#  'filmslists': 1,
#  'givarj': 1,
#  'calderdalecinemas': 1,
#  'charles_page_': 1,
#  'kacha': 2,
#  'rally': 25,
#  'success': 51,
#  'encouragement': 5,
#  'defective': 5,
#  'joongang': 4,
#  'westgate': 1,
#  'resprouts': 1,
#  'pelea': 1,
#  'lyulya': 1,
#  'armagh': 9,
#  'bloomington': 11,
#  'tobias': 6,
#  'orioles': 23,
#  'literate': 1,
#  'countyprimorje': 1,
#  'dholpur': 2,
#  'edinburg': 1,
#  'shakespeare': 18,
#  'gummere': 1,
#  'sakineh': 2,
#  'imperialism': 2,
#  'clavinet': 1,
#  'camper': 2,
#  'frère': 2,
#  'tohoku': 1,
#  'nepil': 2,
#  'khanjan': 1,
#  'wayne': 38,
#  'merrut': 1,
#  'huntingdon': 2,
#  'strano': 1,
#  'levendler': 1,
#  'quinuclidinyl': 1,
#  'lampak': 1,
#  'gorfion': 5,
#  'mumbwa': 1,
#  'mariala': 1,
#  'mezzo': 3,
#  'soler': 1,
#  'осуществлении': 1,
#  'momina': 1,
#  'denopamine': 1,
#  'inherits': 3,
#  'included': 138,
#  'perpetually': 1,
#  'fulfillment': 1,
#  'bracteates': 1,
#  'mueller': 9,
#  'louis_vivet': 1,
#  'divisions': 42,
#  'marches': 5,
#  'borji': 1,
#  'dancy': 8,
#  'balrampur': 2,
#  'ingleborough': 1,
#  'rhodes': 12,
#  'monbetsu': 2,
#  'leighton': 1,
#  'prayed': 2,
#  'given': 112,
#  'preyed': 1,
#  'shamil': 1,
#  'listů': 1,
#  'playerswilliamstown': 1,
#  '83352': 1,
#  'caydee': 2,
#  'fisherman': 8,
#  'branchiosauridae': 1,
#  'clearing': 5,
#  'momna': 1,
#  'symeon_stylites_of_lesbos': 1,
#  'gentiles': 2,
#  'colfax': 1,
#  'laoagtelevision': 1,
#  'spinoff': 2,
#  'filológica': 2,
#  'mickan': 1,
#  'geophysical': 1,
#  'contentarticles': 2,
#  'morin': 4,
#  'kaidu': 1,
#  'casal': 1,
#  'placements': 2,
#  'young': 193,
#  'thaas': 2,
#  'manifesto': 10,
#  'chitradurga': 2,
#  'strack': 3,
#  'brampton': 6,
#  'histone': 2,
#  'kabudlar': 1,
#  'newcomer': 1,
#  'gastritis': 1,
#  'dompremy': 2,
#  '760734376': 1,
#  'donners': 1,
#  'mahtar': 1,
#  'umayyad': 2,
#  'logged': 3,
#  'arabic_toilers': 1,
#  'dashtkar': 1,
#  'proctor': 1,
#  'poonacha': 2,
#  'thibie': 2,
#  'ijresmar': 1,
#  'gontamar': 1,
#  'yorksteamships': 1,
#  'analco': 1,
#  'belval': 4,
#  'ramazanabad': 1,
#  'leaderselijah': 1,
#  'mcclaren': 1,
#  'resided': 2,
#  'yanina': 3,
#  'klopka': 1,
#  'dávila': 3,
#  'exact': 8,
#  'lineage': 17,
#  'waterworks': 2,
#  'inequivalent': 1,
#  'simeon': 3,
#  'shrimp': 1,
#  'stateskorean': 1,
#  'bhikkhuni': 1,
#  'kigeh': 1,
#  'sunday': 21,
#  'sawai': 4,
#  'seaman': 2,
#  'scrapinetti': 1,
#  'magistrate': 3,
#  'gcatholic': 2,
#  'thali': 2,
#  'airtel': 1,
#  'salts': 1,
#  'development1': 1,
#  'microcondylaea': 1,
#  'palauig': 1,
#  'lagunitas': 12,
#  'dartmouth': 16,
#  'varazgah': 1,
#  'igor_and_grichka_bogdanoff': 1,
#  'oprah': 1,
#  'clapton': 1,
#  'roczolod': 1,
#  'dubbing': 4,
#  'phenolic': 1,
#  'spiderman': 1,
#  'luxémont': 2,
#  'openssl': 1,
#  'bouchaïb': 1,
#  'blois': 1,
#  '17515708': 1,
#  'slavi': 1,
#  'kusaka': 5,
#  'rezaqoli': 1,
#  'dandy': 1,
#  'stephenson': 6,
#  'harrysacksioni': 1,
#  'bustards': 3,
#  'methodios': 2,
#  'alinaqi': 1,
#  'render': 4,
#  'helps': 24,
#  'законодательное': 16,
#  'reforma': 1,
#  'bacup': 1,
#  'kabireh': 1,
#  'moffat': 1,
#  'playersserie': 2,
#  'ngalue': 1,
#  'pridacha': 1,
#  'fergus': 2,
#  'captivity': 9,
#  'disproportionately': 1,
#  'chemin': 8,
#  'lombard': 3,
#  'pacheco': 4,
#  'biner': 1,
#  'pohjolan': 2,
#  '20580472': 1,
#  'impériale': 1,
#  'paperny': 1,
#  'fastened': 4,
#  'croatians': 1,
#  'islamabad': 1,
#  'humiliating': 1,
#  'hidrologie': 1,
#  'investigation': 27,
#  'runic': 5,
#  'sotāpatti': 3,
#  'interventionism': 1,
#  '22690499': 1,
#  'embraced': 1,
#  'bootleenglish': 1,
#  'cuciulat': 1,
#  'thwart': 1,
#  'fröjel': 1,
#  'горан': 1,
#  'doumanani': 1,
#  'identified': 30,
#  'selectorshidden': 1,
#  'acetyltransferases': 1,
#  'rozellville': 1,
#  'beheading': 2,
#  'wushu': 2,
#  'murakatnal': 1,
#  'acquires': 3,
#  'laterally': 5,
#  'playersspokane': 1,
#  'davisville': 1,
#  'brize': 1,
#  'appalling': 1,
#  'mountnessing': 1,
#  'ireland': 135,
#  'termsnpov': 1,
#  'thanks_again': 1,
#  'corneilles': 2,
#  'orchestrally': 1,
#  'frontin': 1,
#  'remiz': 1,
#  'smythe': 1,
#  'waverley': 2,
#  'helle': 2,
#  'simulated': 4,
#  'liacouras': 1,
#  'supplement': 5,
#  'lapwings': 3,
#  'cyberpromo': 5,
#  'births1836': 1,
#  'yumiko': 1,
#  'classification': 106,
#  'acquire': 8,
#  'larkinsburg': 1,
#  'ianucci': 1,
#  'kiminobu': 1,
#  'gotta': 3,
#  'batoru': 1,
#  'cbfa2t2': 1,
#  'butadiene': 2,
#  'goldsboro': 1,
#  'fatism': 1,
#  'souls': 3,
#  'hypocrisy': 3,
#  'kuusimäki': 1,
#  'ehsaan': 2,
#  'unless': 8,
#  'tokachi': 2,
#  'feedlots': 1,
#  'darbon': 1,
#  'charterhouse': 1,
#  'mahajan': 2,
#  'imrin': 1,
#  '2568849': 1,
#  'fauntleroy': 1,
#  'recent': 63,
#  '593300': 1,
#  'vaidišová': 3,
#  'leoncheena': 1,
#  'champenoise': 2,
#  'roadie': 1,
#  'duets': 1,
#  'spietata': 1,
#  'fortress': 15,
#  'aarhus': 4,
#  'bocage': 1,
#  'citationspages': 3,
#  'academic': 100,
#  'narrow': 17,
#  'methylenedioxyphenyl': 1,
#  'artcyclopedia': 1,
#  'c69h86br2n16o22': 1,
#  'centrino': 2,
#  'freidrich': 1,
#  'strangely': 1,
#  'antiquities': 5,
#  'studnica': 1,
#  'aşıklı': 1,
#  'chikkamanoli': 1,
#  'salvo': 3,
#  'pohjola': 3,
#  'situational': 1,
#  'anfangsgründe': 2,
#  'niemals': 1,
#  'boylen': 1,
#  '744717616': 1,
#  'apocryphon': 1,
#  'hebbal': 1,
#  'shaob': 1,
#  'rosemary': 8,
#  'suffered': 27,
#  'drafts': 3,
#  'adversaries': 1,
#  'leoben': 1,
#  'buildings': 93,
#  'meten': 1,
#  'cuneopsis': 1,
#  'coquille': 25,
#  'schaffer': 8,
#  'rangaswamy': 1,
#  'exacerbate': 2,
#  'eschew': 1,
#  'debbie': 7,
#  'goldtop': 1,
#  'segue': 1,
#  'specialized': 10,
#  'downing': 4,
#  'gaume': 1,
#  'villenavotte': 1,
#  'ataka': 1,
#  '667728111': 1,
#  'analogs': 3,
#  'multiplayer': 5,
#  'søkortarkiv': 1,
#  'elklick': 1,
#  'creuse': 1,
#  'regents': 5,
#  'eventing': 9,
#  'paintersmodern': 1,
#  'marzes': 1,
#  'lagos': 4,
#  'oldham': 38,
#  'holdenville': 1,
#  'surfaced': 6,
#  'leaks': 5,
#  'jparc': 1,
#  'c1910': 1,
#  'dukkarwadi': 1,
#  'karangasso': 1,
#  'oligarchy': 1,
#  'zenker': 1,
#  'fraley': 1,
#  'mccollum': 2,
#  'keyword': 2,
#  'attabira': 1,
#  'nakina': 1,
#  'massacres': 4,
#  'somidobove': 1,
#  'frères': 2,
#  'ghazban': 1,
#  '86722': 2,
#  'ethic': 2,
#  'prospects': 8,
#  'braziliano': 1,
#  'combatants': 2,
#  '55861': 4,
#  'castaneacuisine': 1,
#  'rochefoucauld': 2,
#  'doubled': 7,
#  'bookended': 1,
#  '1206964': 1,
#  'pashchim': 1,
#  'censor': 5,
#  'frances': 15,
#  'möller': 1,
#  'santer': 2,
#  'glauco': 1,
#  'allies': 28,
#  'eogyrinidae': 1,
#  'infos': 1,
#  'parmi': 1,
#  'urlall': 1,
#  '1508y': 1,
#  'калуга': 3,
#  'maravich': 2,
#  'ayşegül': 1,
#  'mcpyv': 1,
#  'benfeld': 1,
#  'computing': 5,
#  'closely': 16,
#  'collis': 1,
#  'measurements': 7,
#  'unwilling': 1,
#  'colorama': 2,
#  'shivratri': 1,
#  'greenville': 5,
#  'reuniting': 2,
#  '864th': 1,
#  'subprefecture': 19,
#  'terraza': 1,
#  'landon': 1,
#  'n78067959': 1,
#  'acadèmia': 1,
#  'avenuemichigan': 1,
#  'shimshon': 1,
#  'brianbrian': 1,
#  'nederlander': 1,
#  'alumniaustrian': 1,
#  'chronologically': 2,
#  'beltrami': 1,
#  'offutt': 2,
#  'malapa': 1,
#  'lakecountyexam': 3,
#  'aghel': 1,
#  'deathspeople': 19,
#  'chiêm': 1,
#  'guimet': 1,
#  'esatap': 1,
#  'gulliver': 8,
#  'dawdon': 1,
#  'cadbury': 1,
#  'congeniality': 1,
#  'bannockburn': 1,
#  '_kansas': 2,
#  'ántrax': 1,
#  'ultimul': 1,
#  'haemulidae': 1,
#  'gamkonora': 1,
#  'theoristsenglish': 1,
#  'swastika': 2,
#  'luteinizing': 3,
#  'psychopathy': 1,
#  'adrian': 23,
#  'hcards': 25,
#  'musée': 10,
#  'ditch': 2,
#  '25514': 1,
#  'bhutto': 3,
#  'ikast': 1,
#  'scots': 6,
#  'metalarv': 1,
#  'mamaroneck': 1,
#  'surnames': 4,
#  'kilbourn': 3,
#  'nyanaponika': 1,
#  'strange': 15,
#  'officerspeople': 1,
#  'vardhan': 5,
#  'bourges': 1,
#  'jewelz': 4,
#  'megaliths': 1,
#  'sheyenne': 3,
#  'shuttered': 1,
#  'yaamba': 1,
#  'sculpture': 17,
#  'qassab': 4,
#  'panter': 6,
#  'germans': 6,
#  'asienhaus': 1,
#  'mohikaner': 2,
#  '11639': 4,
#  'suits': 2,
#  'bootzheim': 1,
#  'torremejía': 1,
#  'playerssan': 2,
#  'illegally': 3,
#  'edgbaston': 1,
#  'standards1924': 1,
#  'griseus': 1,
#  'talavija': 2,
#  'teruelgeography': 1,
#  'fosaprepitant': 1,
#  'detained': 6,
#  'redesdale': 1,
#  'placeholder': 1,
#  'situates': 1,
#  'myrtopsidoides': 1,
#  'marketplace': 4,
#  'portage': 9,
#  'samoan': 9,
#  'officialsresident': 1,
#  'tportal': 1,
#  '717736459': 1,
#  'tursko': 1,
#  'republic': 234,
#  'denominated': 3,
#  'lalom': 1,
#  'baham': 2,
#  'moons': 4,
#  'dacilor': 1,
#  'bellingshausen': 1,
#  'cobalt': 3,
#  'asiacypriniformes': 1,
#  'akyol': 3,
#  'vanteur': 1,
#  'euctenidiacea': 1,
#  'digiorgio': 24,
#  'lizard': 3,
#  'mocha': 2,
#  'robeson': 1,
#  'moulins': 4,
#  'molden': 2,
#  'lifestories': 2,
#  'gilgal': 1,
#  'scrutinise': 1,
#  'kate_harwood': 1,
#  'grosbeak': 1,
#  'bukowski': 1,
#  'derangement': 1,
#  'locatorcommons': 1,
#  'marts': 1,
#  'contributions': 20,
#  'ensicaen': 1,
#  'golpes': 1,
#  'aisha': 1,
#  'essec': 1,
#  'chaybukha': 1,
#  '729356685': 1,
#  'ledesma': 3,
#  'misspelling': 1,
#  '718955009': 1,
#  'timeanddate': 1,
#  'masbate': 2,
#  'keriya': 6,
#  'similarities': 5,
#  'architectural': 33,
#  'donations': 4,
#  'expressways': 2,
#  'roars': 3,
#  'casimiro': 1,
#  'athletics_at_the_1994_commonwealth_games_': 1,
#  'boorstin': 2,
#  '43724': 1,
#  'nanjing': 6,
#  'aspettano': 1,
#  'athis': 2,
#  'tvøroyri': 1,
#  'illustrator': 13,
#  'chitry': 1,
#  'incipient': 1,
#  '78614': 1,
#  'loess': 1,
#  'oktoberroser': 1,
#  'merit': 23,
#  'births1950': 1,
#  'purnell': 2,
#  'mahamat': 3,
#  'publisher': 30,
#  'syngenor': 9,
#  '55750': 1,
#  'extracellular': 3,
#  'obsessions': 1,
#  'yavuzoğlu': 1,
#  'satyrical': 1,
#  'ratibati': 1,
#  'baixadas': 1,
#  'slacking': 2,
#  'laprida': 1,
#  'mareeze': 1,
#  'mendez': 3,
#  'catalonia': 32,
#  'seeing': 15,
#  '1412544509': 1,
#  'goyet': 1,
#  'olate': 1,
#  'gosport': 3,
#  'accord': 6,
#  'kasay': 1,
#  'wealdstone': 5,
#  'aphalenchoides': 2,
#  'собрание': 18,
#  'frustrated': 1,
#  'preliminarily': 1,
#  'shine': 7,
#  'literaturehidden': 2,
#  'progestogens': 4,
#  'kheyl': 2,
#  'artpetroglyphspre': 1,
#  'outside': 56,
#  'raddho': 1,
#  'mansiysk': 3,
#  'kadishman': 1,
#  'phoenicopteridae': 1,
#  'panik': 1,
#  'amica': 3,
#  'playershidden': 10,
#  'fringilla': 2,
#  'raymond_ii': 1,
#  'infidelity': 1,
#  'nandiya': 2,
#  'citationsuse': 1,
#  'schwarzer': 1,
#  '5866660': 1,
#  'cuarta': 1,
#  'notes': 235,
#  'bighorn': 1,
#  'baalbek': 4,
#  'chartered': 9,
#  'guareña': 1,
#  'àngela': 1,
#  'encountered': 6,
#  '5acting': 1,
#  'enamul_haque_': 1,
#  'aldenhoven': 9,
#  'knightstown': 1,
#  'module': 7,
#  'deductive': 1,
#  'broadbill': 1,
#  'kapala': 4,
#  'jainkoppa': 1,
#  'churchilldisney': 1,
#  'nabgram': 1,
#  'ingaggia': 1,
#  'calderini': 14,
#  'geovisualization': 1,
#  'camelback': 1,
#  'zlotowitz': 13,
#  'raided': 3,
#  'niederschaeffolsheim': 1,
#  'padah': 1,
#  'assaulted': 1,
#  'estelle': 8,
#  'lanneau': 1,
#  'viacamp': 4,
#  'heidberge': 1,
#  'ahmet': 1,
#  '1553a': 3,
#  'cotswold': 2,
#  'sierre': 1,
#  'moukhtara': 1,
#  'carvell': 1,
#  'follicle': 3,
#  'albuquerque': 2,
#  'dkg483': 1,
#  'teamsdefunct': 1,
#  'running': 69,
#  'cardio': 1,
#  'itagüí': 1,
#  'summer': 179,
#  'après': 3,
#  'bisaurri': 4,
#  'sharada': 1,
#  'kapoli': 2,
#  'faiche': 1,
#  'distigmine': 1,
#  'stepsisters': 1,
#  'accuracy': 8,
#  'statutory': 4,
#  'lotus': 8,
#  'floatation': 1,
#  'nigel': 15,
#  'massachusetts1654': 1,
#  'botanická': 2,
#  'estadio_municipal_pozoblanco': 1,
#  'ビギニング': 1,
#  'ammomanes': 1,
#  'uchuu': 1,
#  'ruska': 1,
#  'phala': 3,
#  'arunachal': 3,
#  'leucine': 1,
#  'langha': 1,
#  'pillon': 3,
#  'kedanur': 1,
#  'divani': 1,
#  'geographical': 23,
#  'overly': 1,
#  'donaldson': 3,
#  'bicerin': 1,
#  'cricketersbangladesh': 1,
#  'sorts': 1,
#  'adygea': 1,
#  'subrimosa': 5,
#  'scrum': 3,
#  'fetcenko': 1,
#  'erdelyi': 2,
#  'iommisongs': 1,
#  'shanshan': 8,
#  'grido': 1,
#  'alavoneh': 2,
#  'pollo': 1,
#  'salkisar': 1,
#  'camillo': 4,
#  'evolutions': 1,
#  'xavier': 13,
#  'ernica': 1,
#  'sonnabend': 2,
#  'devanakatti': 1,
#  'panelled': 2,
#  'brighouseenglish': 1,
#  'speciesendemic': 2,
#  'mexicohistoric': 1,
#  'aéronautique': 2,
#  'laurier': 5,
#  'joshjosh': 1,
#  'diesel': 6,
#  'anomaly': 1,
#  'tenis': 1,
#  'armored': 3,
#  'comedies': 2,
#  '_larue_renfroe': 1,
#  'concepción': 4,
#  'albertini': 3,
#  'derisive': 1,
#  'sheriff': 46,
#  'riverin': 1,
#  'np_001287871': 1,
#  'repackage': 1,
#  'hemionana': 1,
#  'teiji_ito': 1,
#  'ridge': 97,
#  'farrokh': 1,
#  'voyeuristic': 1,
#  'quimper': 1,
#  'dying': 10,
#  'blissymbol': 1,
#  'bonnetiers': 1,
#  'balears': 1,
#  'uprising': 10,
#  'layered': 3,
#  'mainz': 9,
#  'tandridge': 2,
#  'ljubo': 1,
#  'sassy': 1,
#  'template': 285,
#  'lenin': 4,
#  'vipr1': 1,
#  'dharmafarers': 5,
#  'outline': 13,
#  'merfy': 2,
#  'nameless': 3,
#  'montanyana': 2,
#  'næstved': 1,
#  'tameside': 3,
#  'grasses': 2,
#  'technologie': 3,
#  '1970treaties': 1,
#  'weekly': 68,
#  'gokai': 2,
#  'blaise': 3,
#  'danylo': 1,
#  'halftime': 3,
#  'polyurethane': 1,
#  'lauterbourg': 2,
#  'hexamethonium': 1,
#  'shinsyu': 1,
#  'estimate': 7,
#  'franklin': 21,
#  'endemic': 16,
#  '734370932': 1,
#  'gouzenko': 1,
#  'oarsman': 1,
#  'hires': 5,
#  'oxyanion': 2,
#  'summoned': 6,
#  'ziabar': 2,
#  'bernard': 28,
#  'bromophenyl': 1,
#  'matanza': 1,
#  'luben': 1,
#  'plaisted': 3,
#  'weisser': 1,
#  'podzun': 1,
#  'vignes': 1,
#  'sullivan': 22,
#  '696204557': 1,
#  'finalization': 1,
#  'centers': 25,
#  'nikah': 1,
#  'enciklopedijų': 1,
#  'rhiannon': 1,
#  'liberec': 8,
#  'ganev': 2,
#  'breakwaters': 1,
#  'galantamine': 4,
#  'represents': 16,
#  'roadside': 3,
#  'klondike': 1,
#  'fides': 1,
#  'abake': 1,
#  'rowdy': 4,
#  'portray': 1,
#  'jeongsun': 1,
#  'nymph': 2,
#  'bastardi': 1,
#  'absurdity': 3,
#  'curators': 1,
#  'mercia': 1,
#  'lynnfield': 3,
#  'cholecystolithiasis': 1,
#  'halligan': 1,
#  'urlchemical': 1,
#  'glsen': 1,
#  'daishugō': 1,
#  'receptionist': 2,
#  'petrosus': 1,
#  'nærøy': 1,
#  'indio': 4,
#  'starry': 1,
#  'general_information': 1,
#  'brillent': 1,
#  'ordinaries': 2,
#  'yaragudri': 2,
#  'compostela': 1,
#  'cervia': 8,
#  'gadfly': 1,
#  'rotherham': 10,
#  'parameterwikipedia': 1,
#  'medalist': 7,
#  'carboniferous': 7,
#  'montrose': 2,
#  'plantshidden': 1,
#  'guimba': 1,
#  'volte': 2,
#  'foradejogo': 1,
#  'monje': 5,
#  'mugenjuku': 2,
#  'yanaizu': 1,
#  'mărului': 1,
#  'hosta': 3,
#  'temefos': 1,
#  'vъsǫdъmь': 1,
#  'climie': 1,
#  'pasillas2010s': 1,
#  'kamberau': 1,
#  'gajjendra': 1,
#  '805th': 4,
#  'frese': 1,
#  'rafik': 1,
#  'suspended': 11,
#  'mackey': 5,
#  'rhind': 1,
#  'playersmalcolm': 1,
#  'maywood': 1,
#  'recall': 7,
#  'kennel': 1,
#  'hanham': 2,
#  'monnens': 1,
#  'sheldon': 7,
#  'packages': 2,
#  'dylan': 30,
#  'whaley': 1,
#  'sumner': 6,
#  'veblin': 1,
#  'feast': 8,
#  'bozen': 1,
#  'rations': 1,
#  'suwannee': 7,
#  'unfriendly': 1,
#  'guides': 3,
#  'tagebücher': 2,
#  'gerrymandering': 1,
#  'dutari': 1,
#  'submitters': 1,
#  'italy5th': 1,
#  'schorn': 1,
#  'ensisa': 1,
#  'stylites': 8,
#  'gitaren': 1,
#  'wince': 1,
#  'saulx': 7,
#  'generator': 2,
#  'rzhevka': 2,
#  'fanciful': 1,
#  'cerca': 3,
#  'mowat': 1,
#  'hiragana': 1,
#  'studentships': 1,
#  'lelli': 1,
#  'briery': 1,
#  'dulci': 1,
#  'knowsley': 2,
#  'toombs': 1,
#  'fates': 2,
#  'changchun': 1,
#  'regular': 79,
#  'ramewadi': 1,
#  'khachaturian': 2,
#  'cookery': 2,
#  'bulges': 1,
#  'friedrich': 28,
#  'bashing': 4,
#  'apostate': 2,
#  'declared': 17,
#  'dalecheh': 1,
#  'forms': 61,
#  'footballersassociation': 8,
#  'anbieter': 1,
#  'fantasies': 1,
#  'lamela': 2,
#  'advancements': 1,
#  'challenges': 6,
#  'conditional': 4,
#  'playland': 1,
#  'erfindung': 1,
#  'apparently': 14,
#  'conditions': 43,
#  'imgrc': 1,
#  'doyist': 1,
#  'ahlfors': 1,
#  'shearwaters': 2,
#  'decisive': 3,
#  'faber': 14,
#  'whitworth': 2,
#  'phoenicurus': 4,
#  'sarzan': 1,
#  'aktobe': 2,
#  ...}

# %% [markdown]
# Only selecting the top 10 words from each article speeds up performance quite a bit.
#
#
# For now, let's answer the question: what articles are most commonly linked to from our articles?
# Only articles name longer than 5 characters will be counted.

# %%
def count_tags(html):
    soup = BeautifulSoup(html, 'html.parser')
    articles = {}
    for tag in soup.find_all('a'):
        if len(tag.text) > 5:
            articles[tag.text] = articles.get(tag.text, 0) + 1
    return articles

start = time.time()
pool = concurrent.futures.ProcessPoolExecutor(max_workers=2)
links_list = pool.map(count_tags, parsed)
links_list = list(links_list)

links = {}
for dict_ in links_list:
    for key in dict_:
        links[key] = links.get(key, 0) + dict_[key]

print(time.time() - start)
# Out:
# 14.515275478363037

# %% [markdown]
# We ran a series of experiments and found out that in this case processes with 2 workers give better speed in comparison with threads. Approximately 13 seconds versus 27 seconds respectively.

# %%
links_dct = links.items() 
sorted(links_dct, key=lambda i: i[1], reverse=True)[:100]
# Out:
# [('navigation', 1000),
#  ('Categories', 999),
#  ('search', 999),
#  ('expanding it', 477),
#  ('All stub articles', 407),
#  ('the original', 251),
#  ('Coordinates', 229),
#  ('Learn how and when to remove this template message', 221),
#  ('Coordinates on Wikidata', 200),
#  ('Living people', 159),
#  ('United States', 119),
#  ('4 References', 114),
#  ('improve this article', 111),
#  ('adding citations to reliable sources', 102),
#  ('citation needed', 98),
#  ('3 References', 96),
#  ('Archived', 94),
#  ('Authority control', 91),
#  ('4 External links', 88),
#  ('West German', 84),
#  ('Wikipedia articles with VIAF identifiers', 84),
#  ('WorldCat Identities', 84),
#  ('5 References', 74),
#  ('Time zone', 74),
#  ('verification', 72),
#  ("Articles with 'species' microformats", 71),
#  ('Scientific classification', 69),
#  ('Articles with hCards', 66),
#  ('Internet Movie Database', 64),
#  ('Pages using deprecated coordinates format', 63),
#  ('Labour', 62),
#  ('All articles with unsourced statements', 61),
#  ('Liberal Democrat', 58),
#  ('England', 57),
#  ('talk page', 56),
#  ('Binomial name', 56),
#  ('6 External links', 56),
#  ('5 External links', 56),
#  ('United States Geological Survey', 56),
#  ('Commons category with local link same as on Wikidata', 54),
#  ('1 History', 54),
#  ('Animalia', 54),
#  ('Pages using ISBN magic links', 54),
#  ('Turnout', 53),
#  ('All articles needing additional references', 53),
#  ('Bolívar', 53),
#  ('Germany', 52),
#  ('Geographic Names Information System', 52),
#  ('Canada', 52),
#  ('Report', 51),
#  ('West Germany', 50),
#  ('Wikipedia articles with LCCN identifiers', 50),
#  ('France', 50),
#  ('Country', 49),
#  ('sources', 48),
#  ('removed', 48),
#  ('Poland', 45),
#  ("Hawke's Bay United", 45),
#  ('Hamilton Wanderers', 44),
#  ('Bogan Shire', 43),
#  ('Tasman United', 43),
#  ('Australia', 42),
#  ('Team Wellington', 42),
#  ('Southern United', 42),
#  ('Jones 1985', 42),
#  ('The Strongest', 42),
#  ('Canterbury United', 42),
#  ('All articles lacking sources', 42),
#  ('Eastern Suburbs', 42),
#  ('Auckland City', 42),
#  ('World War II', 41),
#  ('open-source', 41),
#  ('Wikipedia articles with GND identifiers', 41),
#  ('Waitakere United', 41),
#  ('6 References', 40),
#  ('Switzerland', 40),
#  ('Wikipedia articles with ISNI identifiers', 39),
#  ('Oriente Petrolero', 39),
#  ('Wellington Phoenix', 39),
#  ('permanent dead link', 38),
#  ('Pages using deprecated image syntax', 38),
#  ('4 See also', 38),
#  ('County', 37),
#  ('Official website', 37),
#  ('History', 36),
#  ('3 See also', 36),
#  ('adding to it', 36),
#  ('Auckland', 35),
#  ('campus Lille II', 35),
#  ('Find link tool', 35),
#  ('link to it', 35),
#  ('orphan', 35),
#  ('related articles', 35),
#  ('introduce links', 35),
#  ('Campus USTL Lille I', 35),
#  ('All orphaned articles', 35),
#  ('Conservative', 34),
#  ('Sam Bradford', 34),
#  ('Wikipedia articles with BNF identifiers', 34),
#  ('(data)', 34)]
